# %%
#导入常用库
import sys
import pandas as pd
import os
import random
import shutil
import sklearn
import scipy
import numpy as np
import radiomics  #这个库专门用来提取特征
import SimpleITK as sitk  #读取nii文件
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV#导入Lasso工具包LassoCV
from sklearn.preprocessing import StandardScaler#标准化工具包StandardScaler
import seaborn as sns
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
model_name='model_forest1.model'

radio_datapath=r"E:\liuzhou_breastcancer\radiology\in_sub.csv"
# radio_datapath = r"E:\liuzhou_breastcancer\radiology\subregion_all_radiology_2025-04-16.csv"
# in_datapath = r"E:\liuzhou_breastcancer\radiology\washin_radiology_2024-10-30.csv"
# out_datapath = r"E:\liuzhou_breastcancer\radiology\washout_radiology_2024-10-31.csv"

radio_data=pd.read_csv(radio_datapath)
# in_data=pd.read_csv(in_datapath)
# out_data=pd.read_csv(out_datapath)

radio_data.head()
# Out:
#    index patient_name                         label_name  grade  \
# 0      0            1                    Untitled.nii.gz      0
# 1      1           10                    Untitled.nii.gz      0
# 2      2          101  101-shenmengyun=2021.12.07.nii.gz      0
# 3      3          102                    Untitled.nii.gz      0
# 4      4          103                    Untitled.nii.gz      0
#
#       H1_diagnostics_Configuration_EnabledImageTypes  \
# 0  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 1  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 2  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 3  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 4  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
#
#                H1_diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#    H1_diagnostics_Image-interpolated_Maximum  \
# 0                                   1.569264
# 1                                   2.385270
# 2                                   3.119671
# 3                                   2.376964
# 4                                   2.214178
#
#    H1_diagnostics_Image-interpolated_Mean  \
# 0                                0.179164
# 1                                0.406869
# 2                                0.277952
# 3                                0.249994
# 4                                0.270122
#
#    H1_diagnostics_Image-interpolated_Minimum  \
# 0                                  -0.116257
# 1                                  -0.380712
# 2                                  -0.210979
# 3                                  -0.067903
# 4                                  -0.134521
#
#   H1_diagnostics_Image-interpolated_Size  ...  \
# 0                           (18, 21, 16)  ...
# 1                           (25, 28, 26)  ...
# 2                           (23, 26, 17)  ...
# 3                           (32, 41, 32)  ...
# 4                           (19, 22, 17)  ...
#
#   H3_wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                          20.212054
# 1                                          35.249712
# 2                                          26.303190
# 3                                          16.543406
# 4                                           3.500171
#
#   H3_wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                           0.034402
# 1                                           0.028067
# 2                                           0.077424
# 3                                           0.035031
# 4                                           0.084303
#
#   H3_wavelet-LLL_glszm_ZoneEntropy  H3_wavelet-LLL_glszm_ZonePercentage  \
# 0                         5.043073                             0.186275
# 1                         4.907100                             0.132039
# 2                         3.821928                             0.357143
# 3                         5.458194                             0.159800
# 4                         3.410417                             0.215190
#
#    H3_wavelet-LLL_glszm_ZoneVariance  H3_wavelet-LLL_ngtdm_Busyness  \
# 0                          76.548476                       0.460421
# 1                         356.068123                       0.360614
# 2                           8.560000                       0.143847
# 3                         168.675720                       1.380141
# 4                          26.463668                       0.417161
#
#   H3_wavelet-LLL_ngtdm_Coarseness H3_wavelet-LLL_ngtdm_Complexity  \
# 0                        0.029078                       54.430045
# 1                        0.019357                       74.853288
# 2                        0.102990                       64.625718
# 3                        0.011736                       66.940856
# 4                        0.081698                       24.106272
#
#   H3_wavelet-LLL_ngtdm_Contrast H3_wavelet-LLL_ngtdm_Strength
# 0                      0.062755                      1.300151
# 1                      0.045653                      1.309594
# 2                      0.130364                      4.024960
# 3                      0.055680                      0.777167
# 4                      0.105894                      1.459003
#
# [5 rows x 3511 columns]

# %%
import pandas as pd

# 读取筛选条件表
filter_df = pd.read_csv(r'E:\liuzhou_breastcancer\datas_clear_final.csv')  # 包含 patient_name, label_name, grade

# print(in_sub_data[['patient_name', 'label_name', 'grade']].isin(filter_df[['patient_name', 'label_name', 'grade']]))


for df in [radio_data, filter_df]:
    df['patient_name'] = df['patient_name'].astype(str)
    df['label_name'] = df['label_name'].astype(str)
    df['grade'] = df['grade'].astype(int)


def filter_df_by_conditions(df, filter_df):
    # 合并方式：inner join（多列匹配）
    merged = df.merge(filter_df, on=['patient_name', 'label_name','grade'], how='inner')
    return merged



# in_sub_data = filter_df_by_conditions(in_sub_data, filter_df)
# out_sub_data = filter_df_by_conditions(out_sub_data, filter_df)
radio_data = filter_df_by_conditions(radio_data, filter_df)
# out_data = filter_df_by_conditions(out_data, filter_df)

print("过滤条件数：", len(filter_df))
print("筛选结果行数（in_sub_data）：", len(radio_data))
# 你已有的4个 DataFrame
# 示例：df1, df2, df3, df4
# Out:
# 过滤条件数： 712
# 筛选结果行数（in_sub_data）： 712

# %%
# 查看总数据类别是否平衡
fig, ax = plt.subplots()
# sns.set()
# ax = sns.countplot(x='grade',hue='grade',data=radio_data)
# print(radio_data['grade'].value_counts())

# 计算每个类别的计数
grade_counts = radio_data['grade'].value_counts()

# 绘制条形图
plt.bar(grade_counts.index, grade_counts.values)

# 添加标签和标题
plt.xlabel('Grade')
plt.ylabel('Count')
plt.title('Distribution of Grades')

# 显示图表
plt.show()

# 打印类别计数
print(grade_counts)
# Out:
# grade
# 1    513
# 0    199
# Name: count, dtype: int64

# %%
from pandas.core.common import random_state

#查看总体数据情况
print("一共有{}行特征数据".format(radio_data.shape[0]))
# print("一共有{}列不同特征".format(radio_data.shape[1]))
#再把特征值数据和标签数据分开
# x1=radio_data[radio_data.columns[3:-46]]
# x2=radio_data[radio_data.columns[-23:-4]]
# x1 = x1.reset_index(drop=True)
# x2 = x2.reset_index(drop=True)

x = radio_data[radio_data.columns[4:-5]]
# x2 = in_data[in_data.columns[4:]]
# x3 = out_data[out_data.columns[4:]]

# x2 = x2.add_prefix('*')  # 给 x2 的列名添加前缀 "x2_"
# x3 = x3.add_prefix('**')  # 给 x3 的列名添加前缀 "x3_"

# x = pd.concat([ x1, x3], axis=1)
print("一共有{}列不同特征".format(x.shape[1]))
y = radio_data['grade']
# 取X的5行看看数据
x.head()
# Out:
# 一共有712行特征数据
# 一共有3507列不同特征
#       H1_diagnostics_Configuration_EnabledImageTypes  \
# 0  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 1  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 2  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 3  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 4  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
#
#                H1_diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#    H1_diagnostics_Image-interpolated_Maximum  \
# 0                                   1.569264
# 1                                   2.385270
# 2                                   3.119671
# 3                                   2.376964
# 4                                   2.214178
#
#    H1_diagnostics_Image-interpolated_Mean  \
# 0                                0.179164
# 1                                0.406869
# 2                                0.277952
# 3                                0.249994
# 4                                0.270122
#
#    H1_diagnostics_Image-interpolated_Minimum  \
# 0                                  -0.116257
# 1                                  -0.380712
# 2                                  -0.210979
# 3                                  -0.067903
# 4                                  -0.134521
#
#   H1_diagnostics_Image-interpolated_Size  \
# 0                           (18, 21, 16)
# 1                           (25, 28, 26)
# 2                           (23, 26, 17)
# 3                           (32, 41, 32)
# 4                           (19, 22, 17)
#
#   H1_diagnostics_Image-interpolated_Spacing  \
# 0                         (0.75, 0.75, 1.0)
# 1                         (0.75, 0.75, 1.0)
# 2                         (0.75, 0.75, 1.0)
# 3                         (0.75, 0.75, 1.0)
# 4                         (0.75, 0.75, 1.0)
#
#   H1_diagnostics_Image-original_Dimensionality  \
# 0                                           3D
# 1                                           3D
# 2                                           3D
# 3                                           3D
# 4                                           3D
#
#          H1_diagnostics_Image-original_Hash  \
# 0  31b6d577e8c56b2e68e428a57cddaa5950e96a9b
# 1  a339d708db618d8f2918f4bd38734c1bed0ce455
# 2  7b067e409a53290ed8e2557a7d54ededc46f3860
# 3  e3db39fe9ee33bd8f063943e8e850a295ca1e609
# 4  f099a5b153779af7d57a601002c56f83b314ae6b
#
#    H1_diagnostics_Image-original_Maximum  ...  \
# 0                                      3  ...
# 1                                      3  ...
# 2                                      3  ...
# 3                                      3  ...
# 4                                      3  ...
#
#    H3_wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                          20.212054
# 1                                          35.249712
# 2                                          26.303190
# 3                                          16.543406
# 4                                           3.500171
#
#    H3_wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                           0.034402
# 1                                           0.028067
# 2                                           0.077424
# 3                                           0.035031
# 4                                           0.084303
#
#   H3_wavelet-LLL_glszm_ZoneEntropy H3_wavelet-LLL_glszm_ZonePercentage  \
# 0                         5.043073                            0.186275
# 1                         4.907100                            0.132039
# 2                         3.821928                            0.357143
# 3                         5.458194                            0.159800
# 4                         3.410417                            0.215190
#
#   H3_wavelet-LLL_glszm_ZoneVariance H3_wavelet-LLL_ngtdm_Busyness  \
# 0                         76.548476                      0.460421
# 1                        356.068123                      0.360614
# 2                          8.560000                      0.143847
# 3                        168.675720                      1.380141
# 4                         26.463668                      0.417161
#
#   H3_wavelet-LLL_ngtdm_Coarseness  H3_wavelet-LLL_ngtdm_Complexity  \
# 0                        0.029078                        54.430045
# 1                        0.019357                        74.853288
# 2                        0.102990                        64.625718
# 3                        0.011736                        66.940856
# 4                        0.081698                        24.106272
#
#    H3_wavelet-LLL_ngtdm_Contrast  H3_wavelet-LLL_ngtdm_Strength
# 0                       0.062755                       1.300151
# 1                       0.045653                       1.309594
# 2                       0.130364                       4.024960
# 3                       0.055680                       0.777167
# 4                       0.105894                       1.459003
#
# [5 rows x 3507 columns]

# %%
# 区分训练集和测试集
from sklearn.model_selection import train_test_split
from sklearn import datasets
seed=114514
# 30%用于测试集，70%用于训练集
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.3, stratify=y, random_state=seed)
pd_train=pd.DataFrame(X_train)
train_index=np.array(pd_train.index)
# np.savetxt('../../data/trian_test_csv/train.txt',train_index.astype('int'))
#
# pd_test=pd.DataFrame(X_test)
# test_index=np.array(pd_test.index)
# np.savetxt('../../data/trian_test_csv/test.txt',test_index.astype('int'))
# 打印验证是否随机
print(train_index)
# Out:
# [113 170 282 504 644 534 328 324 241 372  78 530 423 248 269 561 245  15
#  660 621  94 602 146  99  92 440 104 272 443 407  50  68 482 636 110 643
#  707 578 511  53 290 459 312  80 379 502 702 587 473 463 477 249 309 614
#  155 695 517 427 691 692 250 227  95 333 465 317 187 251 118 147 225  70
#  188 371 673 386 399 134 474 261 335  14 653  37 293 635 343 487   2 234
#  563 298 183 649 486 172 686 148 499  75 586 145 662 672 266 260 276 367
#  314 684 453 488 595 554 553 470  57 640 195 352  28  83 611  12 701 566
#  374 645 392   4 394 466 304 539 647 514 174  13  51 143 682 138 189 632
#  625 417 558 412 294 137 288 166 331 544 259 406  89 313 149  87 354 186
#  628 236 238 393 536  74  25 405 125 462  10 297 131 420 300 408 500 200
#  680 397 434 280  82 416 527 634   1 510 360 377 228 202 571  65 507 175
#  219 106 301 535 460 461 639 493 223 638 204 656 698  20 583 355 373 454
#  424 531 538 182   8 568 696 132 190 606  73  72 550   9  39 271  61 150
#  214 206 348 203  98  81 584 321 230 205 179 444 240 278 683 479 112 254
#  681 629 103  76 661  58 252 226 316  62 244 390 361 388 605 340 617 345
#  525 555 323 364 496 111 630  16 191  46 519  97 422 616 217 339 601  48
#   17 439 100 508 512 409 437 700 382 232 387 564 115 346 613 267 581 322
#  705 157 442 572 543 623 357 711 468 196 483 565 302 626 207 426 450 303
#  631 253  88 375  52 609 162 164  71 243 231 620 401 619 135 365 664 246
#  432 159 533 283 574 194 591 421 604 216 140  27  85 275  36   7   6 177
#  273 185 247 380 612 433 215  63 618 306 350 542 697  69 383 589 677 235
#  665 687  90 537 362 559 556 693 428 607 597 396 158 299  19 431 419 167
#  318 648 491 239 471 168 557 515 341 637 265 472  41 154 400 678  66  86
#   40 212 666 363 549 163 657 133 603 429 311 224 403 376 436 332   0 577
#   30 411 369 478 404 457 256 295 120 575 351  11 495 546 435  56 494 445
#  391  47 671 679 402 659 524 342 289 171 109  84 176 513 585 562 650 233
#  389 447 173 579 580 646  96   3 547 102 184 381  24  93 694 425 221 596
#   54 326 588 258 476 358 192 101 551 709 413 108]

# %% [markdown]
# # 特征筛选方法

# %%
# T检验特诊筛选

#通过T检验从106个特征筛选
from scipy.stats import levene, ttest_ind
counts = 0
columns_index =[]
# print(X_train[y_train==0])
for column_name in x.columns[1:]:
    # print(column_name)
    print("\033[1;31;40m"+column_name+"\033[0m")
    try:
        if levene(x[y==0][column_name], x[y==1][column_name])[1] > 0.05:
            if ttest_ind(x[y==0][column_name], x[y==1][column_name],equal_var=True)[1] < 0.05:
                columns_index.append(column_name)
        else:
            if ttest_ind(x[y==0][column_name], x[y==1][column_name],equal_var=False)[1] < 0.05:
                columns_index.append(column_name)
    except Exception as ex:
        print("出现如下异常: %s"%ex)
        continue

print("筛选后剩下的特征数：{}个".format(len(columns_index)))
# Out:
# H1_diagnostics_Configuration_Settings
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Image-interpolated_Maximum
# H1_diagnostics_Image-interpolated_Mean
# H1_diagnostics_Image-interpolated_Minimum
# H1_diagnostics_Image-interpolated_Size
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Image-interpolated_Spacing
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Image-original_Dimensionality
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Image-original_Hash
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Image-original_Maximum
# H1_diagnostics_Image-original_Mean
# H1_diagnostics_Image-original_Minimum
# H1_diagnostics_Image-original_Size
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Image-original_Spacing
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-interpolated_BoundingBox
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-interpolated_CenterOfMass
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-interpolated_CenterOfMassIndex
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-interpolated_Maximum
# H1_diagnostics_Mask-interpolated_Mean
# H1_diagnostics_Mask-interpolated_Minimum
# H1_diagnostics_Mask-interpolated_Size
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-interpolated_Spacing
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-interpolated_VolumeNum
# H1_diagnostics_Mask-interpolated_VoxelNum
# H1_diagnostics_Mask-original_BoundingBox
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-original_CenterOfMass
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-original_CenterOfMassIndex
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-original_Hash
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-original_Size
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-original_Spacing
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Mask-original_VolumeNum
# H1_diagnostics_Mask-original_VoxelNum
# H1_diagnostics_Versions_Numpy
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Versions_PyRadiomics
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Versions_PyWavelet
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Versions_Python
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_diagnostics_Versions_SimpleITK
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_label_name
# 出现如下异常: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# H1_log-sigma-1-0-mm-3D_firstorder_10Percentile
# H1_log-sigma-1-0-mm-3D_firstorder_90Percentile
# H1_log-sigma-1-0-mm-3D_firstorder_Energy
# H1_log-sigma-1-0-mm-3D_firstorder_Entropy
# H1_log-sigma-1-0-mm-3D_firstorder_InterquartileRange
# H1_log-sigma-1-0-mm-3D_firstorder_Kurtosis
# H1_log-sigma-1-0-mm-3D_firstorder_Maximum
# H1_log-sigma-1-0-mm-3D_firstorder_Mean
# H1_log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation
# H1_log-sigma-1-0-mm-3D_firstorder_Median
# H1_log-sigma-1-0-mm-3D_firstorder_Minimum
# H1_log-sigma-1-0-mm-3D_firstorder_Range
# H1_log-sigma-1-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation
# H1_log-sigma-1-0-mm-3D_firstorder_RootMeanSquared
# H1_log-sigma-1-0-mm-3D_firstorder_Skewness
# H1_log-sigma-1-0-mm-3D_firstorder_TotalEnergy
# H1_log-sigma-1-0-mm-3D_firstorder_Uniformity
# H1_log-sigma-1-0-mm-3D_firstorder_Variance
# H1_log-sigma-1-0-mm-3D_glcm_Autocorrelation
# H1_log-sigma-1-0-mm-3D_glcm_ClusterProminence
# H1_log-sigma-1-0-mm-3D_glcm_ClusterShade
# H1_log-sigma-1-0-mm-3D_glcm_ClusterTendency
# H1_log-sigma-1-0-mm-3D_glcm_Contrast
# H1_log-sigma-1-0-mm-3D_glcm_Correlation
# H1_log-sigma-1-0-mm-3D_glcm_DifferenceAverage
# H1_log-sigma-1-0-mm-3D_glcm_DifferenceEntropy
# H1_log-sigma-1-0-mm-3D_glcm_DifferenceVariance
# H1_log-sigma-1-0-mm-3D_glcm_Id
# H1_log-sigma-1-0-mm-3D_glcm_Idm
# H1_log-sigma-1-0-mm-3D_glcm_Idmn
# H1_log-sigma-1-0-mm-3D_glcm_Idn
# H1_log-sigma-1-0-mm-3D_glcm_Imc1
# H1_log-sigma-1-0-mm-3D_glcm_Imc2
# H1_log-sigma-1-0-mm-3D_glcm_InverseVariance
# H1_log-sigma-1-0-mm-3D_glcm_JointAverage
# H1_log-sigma-1-0-mm-3D_glcm_JointEnergy
# H1_log-sigma-1-0-mm-3D_glcm_JointEntropy
# H1_log-sigma-1-0-mm-3D_glcm_MCC
# H1_log-sigma-1-0-mm-3D_glcm_MaximumProbability
# H1_log-sigma-1-0-mm-3D_glcm_SumAverage
# H1_log-sigma-1-0-mm-3D_glcm_SumEntropy
# H1_log-sigma-1-0-mm-3D_glcm_SumSquares
# H1_log-sigma-1-0-mm-3D_gldm_DependenceEntropy
# H1_log-sigma-1-0-mm-3D_gldm_DependenceNonUniformity
# H1_log-sigma-1-0-mm-3D_gldm_DependenceNonUniformityNormalized
# H1_log-sigma-1-0-mm-3D_gldm_DependenceVariance
# H1_log-sigma-1-0-mm-3D_gldm_GrayLevelNonUniformity
# H1_log-sigma-1-0-mm-3D_gldm_GrayLevelVariance
# H1_log-sigma-1-0-mm-3D_gldm_HighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_LargeDependenceEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_SmallDependenceEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformity
# H1_log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized
# H1_log-sigma-1-0-mm-3D_glrlm_GrayLevelVariance
# H1_log-sigma-1-0-mm-3D_glrlm_HighGrayLevelRunEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_LongRunEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_LowGrayLevelRunEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_RunEntropy
# H1_log-sigma-1-0-mm-3D_glrlm_RunLengthNonUniformity
# H1_log-sigma-1-0-mm-3D_glrlm_RunLengthNonUniformityNormalized
# H1_log-sigma-1-0-mm-3D_glrlm_RunPercentage
# H1_log-sigma-1-0-mm-3D_glrlm_RunVariance
# H1_log-sigma-1-0-mm-3D_glrlm_ShortRunEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformity
# H1_log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformityNormalized
# H1_log-sigma-1-0-mm-3D_glszm_GrayLevelVariance
# H1_log-sigma-1-0-mm-3D_glszm_HighGrayLevelZoneEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_LargeAreaEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_LowGrayLevelZoneEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformity
# H1_log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformityNormalized
# H1_log-sigma-1-0-mm-3D_glszm_SmallAreaEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis
# H1_log-sigma-1-0-mm-3D_glszm_ZoneEntropy
# H1_log-sigma-1-0-mm-3D_glszm_ZonePercentage
# H1_log-sigma-1-0-mm-3D_glszm_ZoneVariance
# H1_log-sigma-1-0-mm-3D_ngtdm_Busyness
# H1_log-sigma-1-0-mm-3D_ngtdm_Coarseness
# H1_log-sigma-1-0-mm-3D_ngtdm_Complexity
# H1_log-sigma-1-0-mm-3D_ngtdm_Contrast
# H1_log-sigma-1-0-mm-3D_ngtdm_Strength
# H1_log-sigma-3-0-mm-3D_firstorder_10Percentile
# H1_log-sigma-3-0-mm-3D_firstorder_90Percentile
# H1_log-sigma-3-0-mm-3D_firstorder_Energy
# H1_log-sigma-3-0-mm-3D_firstorder_Entropy
# H1_log-sigma-3-0-mm-3D_firstorder_InterquartileRange
# H1_log-sigma-3-0-mm-3D_firstorder_Kurtosis
# H1_log-sigma-3-0-mm-3D_firstorder_Maximum
# H1_log-sigma-3-0-mm-3D_firstorder_Mean
# H1_log-sigma-3-0-mm-3D_firstorder_MeanAbsoluteDeviation
# H1_log-sigma-3-0-mm-3D_firstorder_Median
# H1_log-sigma-3-0-mm-3D_firstorder_Minimum
# H1_log-sigma-3-0-mm-3D_firstorder_Range
# H1_log-sigma-3-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation
# H1_log-sigma-3-0-mm-3D_firstorder_RootMeanSquared
# H1_log-sigma-3-0-mm-3D_firstorder_Skewness
# H1_log-sigma-3-0-mm-3D_firstorder_TotalEnergy
# H1_log-sigma-3-0-mm-3D_firstorder_Uniformity
# H1_log-sigma-3-0-mm-3D_firstorder_Variance
# H1_log-sigma-3-0-mm-3D_glcm_Autocorrelation
# H1_log-sigma-3-0-mm-3D_glcm_ClusterProminence
# H1_log-sigma-3-0-mm-3D_glcm_ClusterShade
# H1_log-sigma-3-0-mm-3D_glcm_ClusterTendency
# H1_log-sigma-3-0-mm-3D_glcm_Contrast
# H1_log-sigma-3-0-mm-3D_glcm_Correlation
# H1_log-sigma-3-0-mm-3D_glcm_DifferenceAverage
# H1_log-sigma-3-0-mm-3D_glcm_DifferenceEntropy
# H1_log-sigma-3-0-mm-3D_glcm_DifferenceVariance
# H1_log-sigma-3-0-mm-3D_glcm_Id
# H1_log-sigma-3-0-mm-3D_glcm_Idm
# H1_log-sigma-3-0-mm-3D_glcm_Idmn
# H1_log-sigma-3-0-mm-3D_glcm_Idn
# H1_log-sigma-3-0-mm-3D_glcm_Imc1
# H1_log-sigma-3-0-mm-3D_glcm_Imc2
# H1_log-sigma-3-0-mm-3D_glcm_InverseVariance
# H1_log-sigma-3-0-mm-3D_glcm_JointAverage
# H1_log-sigma-3-0-mm-3D_glcm_JointEnergy
# H1_log-sigma-3-0-mm-3D_glcm_JointEntropy
# H1_log-sigma-3-0-mm-3D_glcm_MCC
# H1_log-sigma-3-0-mm-3D_glcm_MaximumProbability
# H1_log-sigma-3-0-mm-3D_glcm_SumAverage
# H1_log-sigma-3-0-mm-3D_glcm_SumEntropy
# H1_log-sigma-3-0-mm-3D_glcm_SumSquares
# H1_log-sigma-3-0-mm-3D_gldm_DependenceEntropy
# H1_log-sigma-3-0-mm-3D_gldm_DependenceNonUniformity
# H1_log-sigma-3-0-mm-3D_gldm_DependenceNonUniformityNormalized
# H1_log-sigma-3-0-mm-3D_gldm_DependenceVariance
# H1_log-sigma-3-0-mm-3D_gldm_GrayLevelNonUniformity
# H1_log-sigma-3-0-mm-3D_gldm_GrayLevelVariance
# H1_log-sigma-3-0-mm-3D_gldm_HighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_LargeDependenceEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_LowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_SmallDependenceEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_GrayLevelNonUniformity
# H1_log-sigma-3-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized
# H1_log-sigma-3-0-mm-3D_glrlm_GrayLevelVariance
# H1_log-sigma-3-0-mm-3D_glrlm_HighGrayLevelRunEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_LongRunEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_LowGrayLevelRunEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_RunEntropy
# H1_log-sigma-3-0-mm-3D_glrlm_RunLengthNonUniformity
# H1_log-sigma-3-0-mm-3D_glrlm_RunLengthNonUniformityNormalized
# H1_log-sigma-3-0-mm-3D_glrlm_RunPercentage
# H1_log-sigma-3-0-mm-3D_glrlm_RunVariance
# H1_log-sigma-3-0-mm-3D_glrlm_ShortRunEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_GrayLevelNonUniformity
# H1_log-sigma-3-0-mm-3D_glszm_GrayLevelNonUniformityNormalized
# H1_log-sigma-3-0-mm-3D_glszm_GrayLevelVariance
# H1_log-sigma-3-0-mm-3D_glszm_HighGrayLevelZoneEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_LargeAreaEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_LowGrayLevelZoneEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_SizeZoneNonUniformity
# H1_log-sigma-3-0-mm-3D_glszm_SizeZoneNonUniformityNormalized
# H1_log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis
# H1_log-sigma-3-0-mm-3D_glszm_ZoneEntropy
# H1_log-sigma-3-0-mm-3D_glszm_ZonePercentage
# H1_log-sigma-3-0-mm-3D_glszm_ZoneVariance
# H1_log-sigma-3-0-mm-3D_ngtdm_Busyness
# H1_log-sigma-3-0-mm-3D_ngtdm_Coarseness
# H1_log-sigma-3-0-mm-3D_ngtdm_Complexity
# H1_log-sigma-3-0-mm-3D_ngtdm_Contrast
# H1_log-sigma-3-0-mm-3D_ngtdm_Strength
# H1_log-sigma-5-0-mm-3D_firstorder_10Percentile
# H1_log-sigma-5-0-mm-3D_firstorder_90Percentile
# H1_log-sigma-5-0-mm-3D_firstorder_Energy
# H1_log-sigma-5-0-mm-3D_firstorder_Entropy
# H1_log-sigma-5-0-mm-3D_firstorder_InterquartileRange
# H1_log-sigma-5-0-mm-3D_firstorder_Kurtosis
# H1_log-sigma-5-0-mm-3D_firstorder_Maximum
# H1_log-sigma-5-0-mm-3D_firstorder_Mean
# H1_log-sigma-5-0-mm-3D_firstorder_MeanAbsoluteDeviation
# H1_log-sigma-5-0-mm-3D_firstorder_Median
# H1_log-sigma-5-0-mm-3D_firstorder_Minimum
# H1_log-sigma-5-0-mm-3D_firstorder_Range
# H1_log-sigma-5-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation
# H1_log-sigma-5-0-mm-3D_firstorder_RootMeanSquared
# H1_log-sigma-5-0-mm-3D_firstorder_Skewness
# H1_log-sigma-5-0-mm-3D_firstorder_TotalEnergy
# H1_log-sigma-5-0-mm-3D_firstorder_Uniformity
# H1_log-sigma-5-0-mm-3D_firstorder_Variance
# H1_log-sigma-5-0-mm-3D_glcm_Autocorrelation
# H1_log-sigma-5-0-mm-3D_glcm_ClusterProminence
# H1_log-sigma-5-0-mm-3D_glcm_ClusterShade
# H1_log-sigma-5-0-mm-3D_glcm_ClusterTendency
# H1_log-sigma-5-0-mm-3D_glcm_Contrast
# H1_log-sigma-5-0-mm-3D_glcm_Correlation
# H1_log-sigma-5-0-mm-3D_glcm_DifferenceAverage
# H1_log-sigma-5-0-mm-3D_glcm_DifferenceEntropy
# H1_log-sigma-5-0-mm-3D_glcm_DifferenceVariance
# H1_log-sigma-5-0-mm-3D_glcm_Id
# H1_log-sigma-5-0-mm-3D_glcm_Idm
# H1_log-sigma-5-0-mm-3D_glcm_Idmn
# H1_log-sigma-5-0-mm-3D_glcm_Idn
# H1_log-sigma-5-0-mm-3D_glcm_Imc1
# H1_log-sigma-5-0-mm-3D_glcm_Imc2
# H1_log-sigma-5-0-mm-3D_glcm_InverseVariance
# H1_log-sigma-5-0-mm-3D_glcm_JointAverage
# H1_log-sigma-5-0-mm-3D_glcm_JointEnergy
# H1_log-sigma-5-0-mm-3D_glcm_JointEntropy
# H1_log-sigma-5-0-mm-3D_glcm_MCC
# H1_log-sigma-5-0-mm-3D_glcm_MaximumProbability
# H1_log-sigma-5-0-mm-3D_glcm_SumAverage
# H1_log-sigma-5-0-mm-3D_glcm_SumEntropy
# H1_log-sigma-5-0-mm-3D_glcm_SumSquares
# H1_log-sigma-5-0-mm-3D_gldm_DependenceEntropy
# H1_log-sigma-5-0-mm-3D_gldm_DependenceNonUniformity
# H1_log-sigma-5-0-mm-3D_gldm_DependenceNonUniformityNormalized
# H1_log-sigma-5-0-mm-3D_gldm_DependenceVariance
# H1_log-sigma-5-0-mm-3D_gldm_GrayLevelNonUniformity
# H1_log-sigma-5-0-mm-3D_gldm_GrayLevelVariance
# H1_log-sigma-5-0-mm-3D_gldm_HighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_LargeDependenceEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_LowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_SmallDependenceEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_GrayLevelNonUniformity
# H1_log-sigma-5-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized
# H1_log-sigma-5-0-mm-3D_glrlm_GrayLevelVariance
# H1_log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_LongRunEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_LowGrayLevelRunEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_RunEntropy
# H1_log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformity
# H1_log-sigma-5-0-mm-3D_glrlm_RunLengthNonUniformityNormalized
# H1_log-sigma-5-0-mm-3D_glrlm_RunPercentage
# H1_log-sigma-5-0-mm-3D_glrlm_RunVariance
# H1_log-sigma-5-0-mm-3D_glrlm_ShortRunEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformity
# H1_log-sigma-5-0-mm-3D_glszm_GrayLevelNonUniformityNormalized
# H1_log-sigma-5-0-mm-3D_glszm_GrayLevelVariance
# H1_log-sigma-5-0-mm-3D_glszm_HighGrayLevelZoneEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_LargeAreaEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_LowGrayLevelZoneEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformity
# H1_log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized
# H1_log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis
# H1_log-sigma-5-0-mm-3D_glszm_ZoneEntropy
# H1_log-sigma-5-0-mm-3D_glszm_ZonePercentage
# H1_log-sigma-5-0-mm-3D_glszm_ZoneVariance
# H1_log-sigma-5-0-mm-3D_ngtdm_Busyness
# H1_log-sigma-5-0-mm-3D_ngtdm_Coarseness
# H1_log-sigma-5-0-mm-3D_ngtdm_Complexity
# H1_log-sigma-5-0-mm-3D_ngtdm_Contrast
# H1_log-sigma-5-0-mm-3D_ngtdm_Strength
# H1_original_firstorder_10Percentile
# H1_original_firstorder_90Percentile
# H1_original_firstorder_Energy
# H1_original_firstorder_Entropy
# H1_original_firstorder_InterquartileRange
# H1_original_firstorder_Kurtosis
# H1_original_firstorder_Maximum
# H1_original_firstorder_Mean
# H1_original_firstorder_MeanAbsoluteDeviation
# H1_original_firstorder_Median
# H1_original_firstorder_Minimum
# H1_original_firstorder_Range
# H1_original_firstorder_RobustMeanAbsoluteDeviation
# H1_original_firstorder_RootMeanSquared
# H1_original_firstorder_Skewness
# H1_original_firstorder_TotalEnergy
# H1_original_firstorder_Uniformity
# H1_original_firstorder_Variance
# H1_original_glcm_Autocorrelation
# H1_original_glcm_ClusterProminence
# H1_original_glcm_ClusterShade
# H1_original_glcm_ClusterTendency
# H1_original_glcm_Contrast
# H1_original_glcm_Correlation
# H1_original_glcm_DifferenceAverage
# H1_original_glcm_DifferenceEntropy
# H1_original_glcm_DifferenceVariance
# H1_original_glcm_Id
# H1_original_glcm_Idm
# H1_original_glcm_Idmn
# H1_original_glcm_Idn
# H1_original_glcm_Imc1
# H1_original_glcm_Imc2
# H1_original_glcm_InverseVariance
# H1_original_glcm_JointAverage
# H1_original_glcm_JointEnergy
# H1_original_glcm_JointEntropy
# H1_original_glcm_MCC
# H1_original_glcm_MaximumProbability
# H1_original_glcm_SumAverage
# H1_original_glcm_SumEntropy
# H1_original_glcm_SumSquares
# H1_original_gldm_DependenceEntropy
# H1_original_gldm_DependenceNonUniformity
# H1_original_gldm_DependenceNonUniformityNormalized
# H1_original_gldm_DependenceVariance
# H1_original_gldm_GrayLevelNonUniformity
# H1_original_gldm_GrayLevelVariance
# H1_original_gldm_HighGrayLevelEmphasis
# H1_original_gldm_LargeDependenceEmphasis
# H1_original_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_original_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_original_gldm_LowGrayLevelEmphasis
# H1_original_gldm_SmallDependenceEmphasis
# H1_original_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_original_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_original_glrlm_GrayLevelNonUniformity
# H1_original_glrlm_GrayLevelNonUniformityNormalized
# H1_original_glrlm_GrayLevelVariance
# H1_original_glrlm_HighGrayLevelRunEmphasis
# H1_original_glrlm_LongRunEmphasis
# H1_original_glrlm_LongRunHighGrayLevelEmphasis
# H1_original_glrlm_LongRunLowGrayLevelEmphasis
# H1_original_glrlm_LowGrayLevelRunEmphasis
# H1_original_glrlm_RunEntropy
# H1_original_glrlm_RunLengthNonUniformity
# H1_original_glrlm_RunLengthNonUniformityNormalized
# H1_original_glrlm_RunPercentage
# H1_original_glrlm_RunVariance
# H1_original_glrlm_ShortRunEmphasis
# H1_original_glrlm_ShortRunHighGrayLevelEmphasis
# H1_original_glrlm_ShortRunLowGrayLevelEmphasis
# H1_original_glszm_GrayLevelNonUniformity
# H1_original_glszm_GrayLevelNonUniformityNormalized
# H1_original_glszm_GrayLevelVariance
# H1_original_glszm_HighGrayLevelZoneEmphasis
# H1_original_glszm_LargeAreaEmphasis
# H1_original_glszm_LargeAreaHighGrayLevelEmphasis
# H1_original_glszm_LargeAreaLowGrayLevelEmphasis
# H1_original_glszm_LowGrayLevelZoneEmphasis
# H1_original_glszm_SizeZoneNonUniformity
# H1_original_glszm_SizeZoneNonUniformityNormalized
# H1_original_glszm_SmallAreaEmphasis
# H1_original_glszm_SmallAreaHighGrayLevelEmphasis
# H1_original_glszm_SmallAreaLowGrayLevelEmphasis
# H1_original_glszm_ZoneEntropy
# H1_original_glszm_ZonePercentage
# H1_original_glszm_ZoneVariance
# H1_original_ngtdm_Busyness
# H1_original_ngtdm_Coarseness
# H1_original_ngtdm_Complexity
# H1_original_ngtdm_Contrast
# H1_original_ngtdm_Strength
# H1_original_shape_Elongation
# H1_original_shape_Flatness
# H1_original_shape_LeastAxisLength
# H1_original_shape_MajorAxisLength
# H1_original_shape_Maximum2DDiameterColumn
# H1_original_shape_Maximum2DDiameterRow
# H1_original_shape_Maximum2DDiameterSlice
# H1_original_shape_Maximum3DDiameter
# H1_original_shape_MeshVolume
# H1_original_shape_MinorAxisLength
# H1_original_shape_Sphericity
# H1_original_shape_SurfaceArea
# H1_original_shape_SurfaceVolumeRatio
# H1_original_shape_VoxelVolume
# H1_patient_name
# 出现如下异常: '<' not supported between instances of 'str' and 'int'
# H1_wavelet-HHH_firstorder_10Percentile
# H1_wavelet-HHH_firstorder_90Percentile
# H1_wavelet-HHH_firstorder_Energy
# H1_wavelet-HHH_firstorder_Entropy
# H1_wavelet-HHH_firstorder_InterquartileRange
# H1_wavelet-HHH_firstorder_Kurtosis
# H1_wavelet-HHH_firstorder_Maximum
# H1_wavelet-HHH_firstorder_Mean
# H1_wavelet-HHH_firstorder_MeanAbsoluteDeviation
# H1_wavelet-HHH_firstorder_Median
# H1_wavelet-HHH_firstorder_Minimum
# H1_wavelet-HHH_firstorder_Range
# H1_wavelet-HHH_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-HHH_firstorder_RootMeanSquared
# H1_wavelet-HHH_firstorder_Skewness
# H1_wavelet-HHH_firstorder_TotalEnergy
# H1_wavelet-HHH_firstorder_Uniformity
# H1_wavelet-HHH_firstorder_Variance
# H1_wavelet-HHH_glcm_Autocorrelation
# H1_wavelet-HHH_glcm_ClusterProminence
# H1_wavelet-HHH_glcm_ClusterShade
# H1_wavelet-HHH_glcm_ClusterTendency
# H1_wavelet-HHH_glcm_Contrast
# H1_wavelet-HHH_glcm_Correlation
# H1_wavelet-HHH_glcm_DifferenceAverage
# H1_wavelet-HHH_glcm_DifferenceEntropy
# H1_wavelet-HHH_glcm_DifferenceVariance
# H1_wavelet-HHH_glcm_Id
# H1_wavelet-HHH_glcm_Idm
# H1_wavelet-HHH_glcm_Idmn
# H1_wavelet-HHH_glcm_Idn
# H1_wavelet-HHH_glcm_Imc1
# H1_wavelet-HHH_glcm_Imc2
# H1_wavelet-HHH_glcm_InverseVariance
# H1_wavelet-HHH_glcm_JointAverage
# H1_wavelet-HHH_glcm_JointEnergy
# H1_wavelet-HHH_glcm_JointEntropy
# H1_wavelet-HHH_glcm_MCC
# H1_wavelet-HHH_glcm_MaximumProbability
# H1_wavelet-HHH_glcm_SumAverage
# H1_wavelet-HHH_glcm_SumEntropy
# H1_wavelet-HHH_glcm_SumSquares
# H1_wavelet-HHH_gldm_DependenceEntropy
# H1_wavelet-HHH_gldm_DependenceNonUniformity
# H1_wavelet-HHH_gldm_DependenceNonUniformityNormalized
# H1_wavelet-HHH_gldm_DependenceVariance
# H1_wavelet-HHH_gldm_GrayLevelNonUniformity
# H1_wavelet-HHH_gldm_GrayLevelVariance
# H1_wavelet-HHH_gldm_HighGrayLevelEmphasis
# H1_wavelet-HHH_gldm_LargeDependenceEmphasis
# H1_wavelet-HHH_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-HHH_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-HHH_gldm_LowGrayLevelEmphasis
# H1_wavelet-HHH_gldm_SmallDependenceEmphasis
# H1_wavelet-HHH_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-HHH_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-HHH_glrlm_GrayLevelNonUniformity
# H1_wavelet-HHH_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-HHH_glrlm_GrayLevelVariance
# H1_wavelet-HHH_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-HHH_glrlm_LongRunEmphasis
# H1_wavelet-HHH_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-HHH_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-HHH_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-HHH_glrlm_RunEntropy
# H1_wavelet-HHH_glrlm_RunLengthNonUniformity
# H1_wavelet-HHH_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-HHH_glrlm_RunPercentage
# H1_wavelet-HHH_glrlm_RunVariance
# H1_wavelet-HHH_glrlm_ShortRunEmphasis
# H1_wavelet-HHH_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-HHH_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-HHH_glszm_GrayLevelNonUniformity
# H1_wavelet-HHH_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-HHH_glszm_GrayLevelVariance
# H1_wavelet-HHH_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-HHH_glszm_LargeAreaEmphasis
# H1_wavelet-HHH_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-HHH_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-HHH_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-HHH_glszm_SizeZoneNonUniformity
# H1_wavelet-HHH_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-HHH_glszm_SmallAreaEmphasis
# H1_wavelet-HHH_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-HHH_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-HHH_glszm_ZoneEntropy
# H1_wavelet-HHH_glszm_ZonePercentage
# H1_wavelet-HHH_glszm_ZoneVariance
# H1_wavelet-HHH_ngtdm_Busyness
# H1_wavelet-HHH_ngtdm_Coarseness
# H1_wavelet-HHH_ngtdm_Complexity
# H1_wavelet-HHH_ngtdm_Contrast
# H1_wavelet-HHH_ngtdm_Strength
# H1_wavelet-HHL_firstorder_10Percentile
# H1_wavelet-HHL_firstorder_90Percentile
# H1_wavelet-HHL_firstorder_Energy
# H1_wavelet-HHL_firstorder_Entropy
# H1_wavelet-HHL_firstorder_InterquartileRange
# H1_wavelet-HHL_firstorder_Kurtosis
# H1_wavelet-HHL_firstorder_Maximum
# H1_wavelet-HHL_firstorder_Mean
# H1_wavelet-HHL_firstorder_MeanAbsoluteDeviation
# H1_wavelet-HHL_firstorder_Median
# H1_wavelet-HHL_firstorder_Minimum
# H1_wavelet-HHL_firstorder_Range
# H1_wavelet-HHL_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-HHL_firstorder_RootMeanSquared
# H1_wavelet-HHL_firstorder_Skewness
# H1_wavelet-HHL_firstorder_TotalEnergy
# H1_wavelet-HHL_firstorder_Uniformity
# H1_wavelet-HHL_firstorder_Variance
# H1_wavelet-HHL_glcm_Autocorrelation
# H1_wavelet-HHL_glcm_ClusterProminence
# H1_wavelet-HHL_glcm_ClusterShade
# H1_wavelet-HHL_glcm_ClusterTendency
# H1_wavelet-HHL_glcm_Contrast
# H1_wavelet-HHL_glcm_Correlation
# H1_wavelet-HHL_glcm_DifferenceAverage
# H1_wavelet-HHL_glcm_DifferenceEntropy
# H1_wavelet-HHL_glcm_DifferenceVariance
# H1_wavelet-HHL_glcm_Id
# H1_wavelet-HHL_glcm_Idm
# H1_wavelet-HHL_glcm_Idmn
# H1_wavelet-HHL_glcm_Idn
# H1_wavelet-HHL_glcm_Imc1
# H1_wavelet-HHL_glcm_Imc2
# H1_wavelet-HHL_glcm_InverseVariance
# H1_wavelet-HHL_glcm_JointAverage
# H1_wavelet-HHL_glcm_JointEnergy
# H1_wavelet-HHL_glcm_JointEntropy
# H1_wavelet-HHL_glcm_MCC
# H1_wavelet-HHL_glcm_MaximumProbability
# H1_wavelet-HHL_glcm_SumAverage
# H1_wavelet-HHL_glcm_SumEntropy
# H1_wavelet-HHL_glcm_SumSquares
# H1_wavelet-HHL_gldm_DependenceEntropy
# H1_wavelet-HHL_gldm_DependenceNonUniformity
# H1_wavelet-HHL_gldm_DependenceNonUniformityNormalized
# H1_wavelet-HHL_gldm_DependenceVariance
# H1_wavelet-HHL_gldm_GrayLevelNonUniformity
# H1_wavelet-HHL_gldm_GrayLevelVariance
# H1_wavelet-HHL_gldm_HighGrayLevelEmphasis
# H1_wavelet-HHL_gldm_LargeDependenceEmphasis
# H1_wavelet-HHL_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-HHL_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-HHL_gldm_LowGrayLevelEmphasis
# H1_wavelet-HHL_gldm_SmallDependenceEmphasis
# H1_wavelet-HHL_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-HHL_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-HHL_glrlm_GrayLevelNonUniformity
# H1_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-HHL_glrlm_GrayLevelVariance
# H1_wavelet-HHL_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-HHL_glrlm_LongRunEmphasis
# H1_wavelet-HHL_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-HHL_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-HHL_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-HHL_glrlm_RunEntropy
# H1_wavelet-HHL_glrlm_RunLengthNonUniformity
# H1_wavelet-HHL_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-HHL_glrlm_RunPercentage
# H1_wavelet-HHL_glrlm_RunVariance
# H1_wavelet-HHL_glrlm_ShortRunEmphasis
# H1_wavelet-HHL_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-HHL_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-HHL_glszm_GrayLevelNonUniformity
# H1_wavelet-HHL_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-HHL_glszm_GrayLevelVariance
# H1_wavelet-HHL_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-HHL_glszm_LargeAreaEmphasis
# H1_wavelet-HHL_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-HHL_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-HHL_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-HHL_glszm_SizeZoneNonUniformity
# H1_wavelet-HHL_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-HHL_glszm_SmallAreaEmphasis
# H1_wavelet-HHL_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-HHL_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-HHL_glszm_ZoneEntropy
# H1_wavelet-HHL_glszm_ZonePercentage
# H1_wavelet-HHL_glszm_ZoneVariance
# H1_wavelet-HHL_ngtdm_Busyness
# H1_wavelet-HHL_ngtdm_Coarseness
# H1_wavelet-HHL_ngtdm_Complexity
# H1_wavelet-HHL_ngtdm_Contrast
# H1_wavelet-HHL_ngtdm_Strength
# H1_wavelet-HLH_firstorder_10Percentile
# H1_wavelet-HLH_firstorder_90Percentile
# H1_wavelet-HLH_firstorder_Energy
# H1_wavelet-HLH_firstorder_Entropy
# H1_wavelet-HLH_firstorder_InterquartileRange
# H1_wavelet-HLH_firstorder_Kurtosis
# H1_wavelet-HLH_firstorder_Maximum
# H1_wavelet-HLH_firstorder_Mean
# H1_wavelet-HLH_firstorder_MeanAbsoluteDeviation
# H1_wavelet-HLH_firstorder_Median
# H1_wavelet-HLH_firstorder_Minimum
# H1_wavelet-HLH_firstorder_Range
# H1_wavelet-HLH_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-HLH_firstorder_RootMeanSquared
# H1_wavelet-HLH_firstorder_Skewness
# H1_wavelet-HLH_firstorder_TotalEnergy
# H1_wavelet-HLH_firstorder_Uniformity
# H1_wavelet-HLH_firstorder_Variance
# H1_wavelet-HLH_glcm_Autocorrelation
# H1_wavelet-HLH_glcm_ClusterProminence
# H1_wavelet-HLH_glcm_ClusterShade
# H1_wavelet-HLH_glcm_ClusterTendency
# H1_wavelet-HLH_glcm_Contrast
# H1_wavelet-HLH_glcm_Correlation
# H1_wavelet-HLH_glcm_DifferenceAverage
# H1_wavelet-HLH_glcm_DifferenceEntropy
# H1_wavelet-HLH_glcm_DifferenceVariance
# H1_wavelet-HLH_glcm_Id
# H1_wavelet-HLH_glcm_Idm
# H1_wavelet-HLH_glcm_Idmn
# H1_wavelet-HLH_glcm_Idn
# H1_wavelet-HLH_glcm_Imc1
# H1_wavelet-HLH_glcm_Imc2
# H1_wavelet-HLH_glcm_InverseVariance
# H1_wavelet-HLH_glcm_JointAverage
# H1_wavelet-HLH_glcm_JointEnergy
# H1_wavelet-HLH_glcm_JointEntropy
# H1_wavelet-HLH_glcm_MCC
# H1_wavelet-HLH_glcm_MaximumProbability
# H1_wavelet-HLH_glcm_SumAverage
# H1_wavelet-HLH_glcm_SumEntropy
# H1_wavelet-HLH_glcm_SumSquares
# H1_wavelet-HLH_gldm_DependenceEntropy
# H1_wavelet-HLH_gldm_DependenceNonUniformity
# H1_wavelet-HLH_gldm_DependenceNonUniformityNormalized
# H1_wavelet-HLH_gldm_DependenceVariance
# H1_wavelet-HLH_gldm_GrayLevelNonUniformity
# H1_wavelet-HLH_gldm_GrayLevelVariance
# H1_wavelet-HLH_gldm_HighGrayLevelEmphasis
# H1_wavelet-HLH_gldm_LargeDependenceEmphasis
# H1_wavelet-HLH_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-HLH_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-HLH_gldm_LowGrayLevelEmphasis
# H1_wavelet-HLH_gldm_SmallDependenceEmphasis
# H1_wavelet-HLH_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-HLH_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-HLH_glrlm_GrayLevelNonUniformity
# H1_wavelet-HLH_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-HLH_glrlm_GrayLevelVariance
# H1_wavelet-HLH_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-HLH_glrlm_LongRunEmphasis
# H1_wavelet-HLH_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-HLH_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-HLH_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-HLH_glrlm_RunEntropy
# H1_wavelet-HLH_glrlm_RunLengthNonUniformity
# H1_wavelet-HLH_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-HLH_glrlm_RunPercentage
# H1_wavelet-HLH_glrlm_RunVariance
# H1_wavelet-HLH_glrlm_ShortRunEmphasis
# H1_wavelet-HLH_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-HLH_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-HLH_glszm_GrayLevelNonUniformity
# H1_wavelet-HLH_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-HLH_glszm_GrayLevelVariance
# H1_wavelet-HLH_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-HLH_glszm_LargeAreaEmphasis
# H1_wavelet-HLH_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-HLH_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-HLH_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-HLH_glszm_SizeZoneNonUniformity
# H1_wavelet-HLH_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-HLH_glszm_SmallAreaEmphasis
# H1_wavelet-HLH_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-HLH_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-HLH_glszm_ZoneEntropy
# H1_wavelet-HLH_glszm_ZonePercentage
# H1_wavelet-HLH_glszm_ZoneVariance
# H1_wavelet-HLH_ngtdm_Busyness
# H1_wavelet-HLH_ngtdm_Coarseness
# H1_wavelet-HLH_ngtdm_Complexity
# H1_wavelet-HLH_ngtdm_Contrast
# H1_wavelet-HLH_ngtdm_Strength
# H1_wavelet-HLL_firstorder_10Percentile
# H1_wavelet-HLL_firstorder_90Percentile
# H1_wavelet-HLL_firstorder_Energy
# H1_wavelet-HLL_firstorder_Entropy
# H1_wavelet-HLL_firstorder_InterquartileRange
# H1_wavelet-HLL_firstorder_Kurtosis
# H1_wavelet-HLL_firstorder_Maximum
# H1_wavelet-HLL_firstorder_Mean
# H1_wavelet-HLL_firstorder_MeanAbsoluteDeviation
# H1_wavelet-HLL_firstorder_Median
# H1_wavelet-HLL_firstorder_Minimum
# H1_wavelet-HLL_firstorder_Range
# H1_wavelet-HLL_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-HLL_firstorder_RootMeanSquared
# H1_wavelet-HLL_firstorder_Skewness
# H1_wavelet-HLL_firstorder_TotalEnergy
# H1_wavelet-HLL_firstorder_Uniformity
# H1_wavelet-HLL_firstorder_Variance
# H1_wavelet-HLL_glcm_Autocorrelation
# H1_wavelet-HLL_glcm_ClusterProminence
# H1_wavelet-HLL_glcm_ClusterShade
# H1_wavelet-HLL_glcm_ClusterTendency
# H1_wavelet-HLL_glcm_Contrast
# H1_wavelet-HLL_glcm_Correlation
# H1_wavelet-HLL_glcm_DifferenceAverage
# H1_wavelet-HLL_glcm_DifferenceEntropy
# H1_wavelet-HLL_glcm_DifferenceVariance
# H1_wavelet-HLL_glcm_Id
# H1_wavelet-HLL_glcm_Idm
# H1_wavelet-HLL_glcm_Idmn
# H1_wavelet-HLL_glcm_Idn
# H1_wavelet-HLL_glcm_Imc1
# H1_wavelet-HLL_glcm_Imc2
# H1_wavelet-HLL_glcm_InverseVariance
# H1_wavelet-HLL_glcm_JointAverage
# H1_wavelet-HLL_glcm_JointEnergy
# H1_wavelet-HLL_glcm_JointEntropy
# H1_wavelet-HLL_glcm_MCC
# H1_wavelet-HLL_glcm_MaximumProbability
# H1_wavelet-HLL_glcm_SumAverage
# H1_wavelet-HLL_glcm_SumEntropy
# H1_wavelet-HLL_glcm_SumSquares
# H1_wavelet-HLL_gldm_DependenceEntropy
# H1_wavelet-HLL_gldm_DependenceNonUniformity
# H1_wavelet-HLL_gldm_DependenceNonUniformityNormalized
# H1_wavelet-HLL_gldm_DependenceVariance
# H1_wavelet-HLL_gldm_GrayLevelNonUniformity
# H1_wavelet-HLL_gldm_GrayLevelVariance
# H1_wavelet-HLL_gldm_HighGrayLevelEmphasis
# H1_wavelet-HLL_gldm_LargeDependenceEmphasis
# H1_wavelet-HLL_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-HLL_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-HLL_gldm_LowGrayLevelEmphasis
# H1_wavelet-HLL_gldm_SmallDependenceEmphasis
# H1_wavelet-HLL_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-HLL_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-HLL_glrlm_GrayLevelNonUniformity
# H1_wavelet-HLL_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-HLL_glrlm_GrayLevelVariance
# H1_wavelet-HLL_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-HLL_glrlm_LongRunEmphasis
# H1_wavelet-HLL_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-HLL_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-HLL_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-HLL_glrlm_RunEntropy
# H1_wavelet-HLL_glrlm_RunLengthNonUniformity
# H1_wavelet-HLL_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-HLL_glrlm_RunPercentage
# H1_wavelet-HLL_glrlm_RunVariance
# H1_wavelet-HLL_glrlm_ShortRunEmphasis
# H1_wavelet-HLL_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-HLL_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-HLL_glszm_GrayLevelNonUniformity
# H1_wavelet-HLL_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-HLL_glszm_GrayLevelVariance
# H1_wavelet-HLL_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-HLL_glszm_LargeAreaEmphasis
# H1_wavelet-HLL_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-HLL_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-HLL_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-HLL_glszm_SizeZoneNonUniformity
# H1_wavelet-HLL_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-HLL_glszm_SmallAreaEmphasis
# H1_wavelet-HLL_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-HLL_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-HLL_glszm_ZoneEntropy
# H1_wavelet-HLL_glszm_ZonePercentage
# H1_wavelet-HLL_glszm_ZoneVariance
# H1_wavelet-HLL_ngtdm_Busyness
# H1_wavelet-HLL_ngtdm_Coarseness
# H1_wavelet-HLL_ngtdm_Complexity
# H1_wavelet-HLL_ngtdm_Contrast
# H1_wavelet-HLL_ngtdm_Strength
# H1_wavelet-LHH_firstorder_10Percentile
# H1_wavelet-LHH_firstorder_90Percentile
# H1_wavelet-LHH_firstorder_Energy
# H1_wavelet-LHH_firstorder_Entropy
# H1_wavelet-LHH_firstorder_InterquartileRange
# H1_wavelet-LHH_firstorder_Kurtosis
# H1_wavelet-LHH_firstorder_Maximum
# H1_wavelet-LHH_firstorder_Mean
# H1_wavelet-LHH_firstorder_MeanAbsoluteDeviation
# H1_wavelet-LHH_firstorder_Median
# H1_wavelet-LHH_firstorder_Minimum
# H1_wavelet-LHH_firstorder_Range
# H1_wavelet-LHH_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-LHH_firstorder_RootMeanSquared
# H1_wavelet-LHH_firstorder_Skewness
# H1_wavelet-LHH_firstorder_TotalEnergy
# H1_wavelet-LHH_firstorder_Uniformity
# H1_wavelet-LHH_firstorder_Variance
# H1_wavelet-LHH_glcm_Autocorrelation
# H1_wavelet-LHH_glcm_ClusterProminence
# H1_wavelet-LHH_glcm_ClusterShade
# H1_wavelet-LHH_glcm_ClusterTendency
# H1_wavelet-LHH_glcm_Contrast
# H1_wavelet-LHH_glcm_Correlation
# H1_wavelet-LHH_glcm_DifferenceAverage
# H1_wavelet-LHH_glcm_DifferenceEntropy
# H1_wavelet-LHH_glcm_DifferenceVariance
# H1_wavelet-LHH_glcm_Id
# H1_wavelet-LHH_glcm_Idm
# H1_wavelet-LHH_glcm_Idmn
# H1_wavelet-LHH_glcm_Idn
# H1_wavelet-LHH_glcm_Imc1
# H1_wavelet-LHH_glcm_Imc2
# H1_wavelet-LHH_glcm_InverseVariance
# H1_wavelet-LHH_glcm_JointAverage
# H1_wavelet-LHH_glcm_JointEnergy
# H1_wavelet-LHH_glcm_JointEntropy
# H1_wavelet-LHH_glcm_MCC
# H1_wavelet-LHH_glcm_MaximumProbability
# H1_wavelet-LHH_glcm_SumAverage
# H1_wavelet-LHH_glcm_SumEntropy
# H1_wavelet-LHH_glcm_SumSquares
# H1_wavelet-LHH_gldm_DependenceEntropy
# H1_wavelet-LHH_gldm_DependenceNonUniformity
# H1_wavelet-LHH_gldm_DependenceNonUniformityNormalized
# H1_wavelet-LHH_gldm_DependenceVariance
# H1_wavelet-LHH_gldm_GrayLevelNonUniformity
# H1_wavelet-LHH_gldm_GrayLevelVariance
# H1_wavelet-LHH_gldm_HighGrayLevelEmphasis
# H1_wavelet-LHH_gldm_LargeDependenceEmphasis
# H1_wavelet-LHH_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-LHH_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-LHH_gldm_LowGrayLevelEmphasis
# H1_wavelet-LHH_gldm_SmallDependenceEmphasis
# H1_wavelet-LHH_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-LHH_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-LHH_glrlm_GrayLevelNonUniformity
# H1_wavelet-LHH_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-LHH_glrlm_GrayLevelVariance
# H1_wavelet-LHH_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-LHH_glrlm_LongRunEmphasis
# H1_wavelet-LHH_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-LHH_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-LHH_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-LHH_glrlm_RunEntropy
# H1_wavelet-LHH_glrlm_RunLengthNonUniformity
# H1_wavelet-LHH_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-LHH_glrlm_RunPercentage
# H1_wavelet-LHH_glrlm_RunVariance
# H1_wavelet-LHH_glrlm_ShortRunEmphasis
# H1_wavelet-LHH_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-LHH_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-LHH_glszm_GrayLevelNonUniformity
# H1_wavelet-LHH_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-LHH_glszm_GrayLevelVariance
# H1_wavelet-LHH_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-LHH_glszm_LargeAreaEmphasis
# H1_wavelet-LHH_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-LHH_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-LHH_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-LHH_glszm_SizeZoneNonUniformity
# H1_wavelet-LHH_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-LHH_glszm_SmallAreaEmphasis
# H1_wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-LHH_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-LHH_glszm_ZoneEntropy
# H1_wavelet-LHH_glszm_ZonePercentage
# H1_wavelet-LHH_glszm_ZoneVariance
# H1_wavelet-LHH_ngtdm_Busyness
# H1_wavelet-LHH_ngtdm_Coarseness
# H1_wavelet-LHH_ngtdm_Complexity
# H1_wavelet-LHH_ngtdm_Contrast
# H1_wavelet-LHH_ngtdm_Strength
# H1_wavelet-LHL_firstorder_10Percentile
# H1_wavelet-LHL_firstorder_90Percentile
# H1_wavelet-LHL_firstorder_Energy
# H1_wavelet-LHL_firstorder_Entropy
# H1_wavelet-LHL_firstorder_InterquartileRange
# H1_wavelet-LHL_firstorder_Kurtosis
# H1_wavelet-LHL_firstorder_Maximum
# H1_wavelet-LHL_firstorder_Mean
# H1_wavelet-LHL_firstorder_MeanAbsoluteDeviation
# H1_wavelet-LHL_firstorder_Median
# H1_wavelet-LHL_firstorder_Minimum
# H1_wavelet-LHL_firstorder_Range
# H1_wavelet-LHL_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-LHL_firstorder_RootMeanSquared
# H1_wavelet-LHL_firstorder_Skewness
# H1_wavelet-LHL_firstorder_TotalEnergy
# H1_wavelet-LHL_firstorder_Uniformity
# H1_wavelet-LHL_firstorder_Variance
# H1_wavelet-LHL_glcm_Autocorrelation
# H1_wavelet-LHL_glcm_ClusterProminence
# H1_wavelet-LHL_glcm_ClusterShade
# H1_wavelet-LHL_glcm_ClusterTendency
# H1_wavelet-LHL_glcm_Contrast
# H1_wavelet-LHL_glcm_Correlation
# H1_wavelet-LHL_glcm_DifferenceAverage
# H1_wavelet-LHL_glcm_DifferenceEntropy
# H1_wavelet-LHL_glcm_DifferenceVariance
# H1_wavelet-LHL_glcm_Id
# H1_wavelet-LHL_glcm_Idm
# H1_wavelet-LHL_glcm_Idmn
# H1_wavelet-LHL_glcm_Idn
# H1_wavelet-LHL_glcm_Imc1
# H1_wavelet-LHL_glcm_Imc2
# H1_wavelet-LHL_glcm_InverseVariance
# H1_wavelet-LHL_glcm_JointAverage
# H1_wavelet-LHL_glcm_JointEnergy
# H1_wavelet-LHL_glcm_JointEntropy
# H1_wavelet-LHL_glcm_MCC
# H1_wavelet-LHL_glcm_MaximumProbability
# H1_wavelet-LHL_glcm_SumAverage
# H1_wavelet-LHL_glcm_SumEntropy
# H1_wavelet-LHL_glcm_SumSquares
# H1_wavelet-LHL_gldm_DependenceEntropy
# H1_wavelet-LHL_gldm_DependenceNonUniformity
# H1_wavelet-LHL_gldm_DependenceNonUniformityNormalized
# H1_wavelet-LHL_gldm_DependenceVariance
# H1_wavelet-LHL_gldm_GrayLevelNonUniformity
# H1_wavelet-LHL_gldm_GrayLevelVariance
# H1_wavelet-LHL_gldm_HighGrayLevelEmphasis
# H1_wavelet-LHL_gldm_LargeDependenceEmphasis
# H1_wavelet-LHL_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-LHL_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-LHL_gldm_LowGrayLevelEmphasis
# H1_wavelet-LHL_gldm_SmallDependenceEmphasis
# H1_wavelet-LHL_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-LHL_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-LHL_glrlm_GrayLevelNonUniformity
# H1_wavelet-LHL_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-LHL_glrlm_GrayLevelVariance
# H1_wavelet-LHL_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-LHL_glrlm_LongRunEmphasis
# H1_wavelet-LHL_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-LHL_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-LHL_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-LHL_glrlm_RunEntropy
# H1_wavelet-LHL_glrlm_RunLengthNonUniformity
# H1_wavelet-LHL_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-LHL_glrlm_RunPercentage
# H1_wavelet-LHL_glrlm_RunVariance
# H1_wavelet-LHL_glrlm_ShortRunEmphasis
# H1_wavelet-LHL_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-LHL_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-LHL_glszm_GrayLevelNonUniformity
# H1_wavelet-LHL_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-LHL_glszm_GrayLevelVariance
# H1_wavelet-LHL_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-LHL_glszm_LargeAreaEmphasis
# H1_wavelet-LHL_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-LHL_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-LHL_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-LHL_glszm_SizeZoneNonUniformity
# H1_wavelet-LHL_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-LHL_glszm_SmallAreaEmphasis
# H1_wavelet-LHL_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-LHL_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-LHL_glszm_ZoneEntropy
# H1_wavelet-LHL_glszm_ZonePercentage
# H1_wavelet-LHL_glszm_ZoneVariance
# H1_wavelet-LHL_ngtdm_Busyness
# H1_wavelet-LHL_ngtdm_Coarseness
# H1_wavelet-LHL_ngtdm_Complexity
# H1_wavelet-LHL_ngtdm_Contrast
# H1_wavelet-LHL_ngtdm_Strength
# H1_wavelet-LLH_firstorder_10Percentile
# H1_wavelet-LLH_firstorder_90Percentile
# H1_wavelet-LLH_firstorder_Energy
# H1_wavelet-LLH_firstorder_Entropy
# H1_wavelet-LLH_firstorder_InterquartileRange
# H1_wavelet-LLH_firstorder_Kurtosis
# H1_wavelet-LLH_firstorder_Maximum
# H1_wavelet-LLH_firstorder_Mean
# H1_wavelet-LLH_firstorder_MeanAbsoluteDeviation
# H1_wavelet-LLH_firstorder_Median
# H1_wavelet-LLH_firstorder_Minimum
# H1_wavelet-LLH_firstorder_Range
# H1_wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation
# H1_wavelet-LLH_firstorder_RootMeanSquared
# H1_wavelet-LLH_firstorder_Skewness
# H1_wavelet-LLH_firstorder_TotalEnergy
# H1_wavelet-LLH_firstorder_Uniformity
# H1_wavelet-LLH_firstorder_Variance
# H1_wavelet-LLH_glcm_Autocorrelation
# H1_wavelet-LLH_glcm_ClusterProminence
# H1_wavelet-LLH_glcm_ClusterShade
# H1_wavelet-LLH_glcm_ClusterTendency
# H1_wavelet-LLH_glcm_Contrast
# H1_wavelet-LLH_glcm_Correlation
# H1_wavelet-LLH_glcm_DifferenceAverage
# H1_wavelet-LLH_glcm_DifferenceEntropy
# H1_wavelet-LLH_glcm_DifferenceVariance
# H1_wavelet-LLH_glcm_Id
# H1_wavelet-LLH_glcm_Idm
# H1_wavelet-LLH_glcm_Idmn
# H1_wavelet-LLH_glcm_Idn
# H1_wavelet-LLH_glcm_Imc1
# H1_wavelet-LLH_glcm_Imc2
# H1_wavelet-LLH_glcm_InverseVariance
# H1_wavelet-LLH_glcm_JointAverage
# H1_wavelet-LLH_glcm_JointEnergy
# H1_wavelet-LLH_glcm_JointEntropy
# H1_wavelet-LLH_glcm_MCC
# H1_wavelet-LLH_glcm_MaximumProbability
# H1_wavelet-LLH_glcm_SumAverage
# H1_wavelet-LLH_glcm_SumEntropy
# H1_wavelet-LLH_glcm_SumSquares
# H1_wavelet-LLH_gldm_DependenceEntropy
# H1_wavelet-LLH_gldm_DependenceNonUniformity
# H1_wavelet-LLH_gldm_DependenceNonUniformityNormalized
# H1_wavelet-LLH_gldm_DependenceVariance
# H1_wavelet-LLH_gldm_GrayLevelNonUniformity
# H1_wavelet-LLH_gldm_GrayLevelVariance
# H1_wavelet-LLH_gldm_HighGrayLevelEmphasis
# H1_wavelet-LLH_gldm_LargeDependenceEmphasis
# H1_wavelet-LLH_gldm_LargeDependenceHighGrayLevelEmphasis
# H1_wavelet-LLH_gldm_LargeDependenceLowGrayLevelEmphasis
# H1_wavelet-LLH_gldm_LowGrayLevelEmphasis
# H1_wavelet-LLH_gldm_SmallDependenceEmphasis
# H1_wavelet-LLH_gldm_SmallDependenceHighGrayLevelEmphasis
# H1_wavelet-LLH_gldm_SmallDependenceLowGrayLevelEmphasis
# H1_wavelet-LLH_glrlm_GrayLevelNonUniformity
# H1_wavelet-LLH_glrlm_GrayLevelNonUniformityNormalized
# H1_wavelet-LLH_glrlm_GrayLevelVariance
# H1_wavelet-LLH_glrlm_HighGrayLevelRunEmphasis
# H1_wavelet-LLH_glrlm_LongRunEmphasis
# H1_wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis
# H1_wavelet-LLH_glrlm_LongRunLowGrayLevelEmphasis
# H1_wavelet-LLH_glrlm_LowGrayLevelRunEmphasis
# H1_wavelet-LLH_glrlm_RunEntropy
# H1_wavelet-LLH_glrlm_RunLengthNonUniformity
# H1_wavelet-LLH_glrlm_RunLengthNonUniformityNormalized
# H1_wavelet-LLH_glrlm_RunPercentage
# H1_wavelet-LLH_glrlm_RunVariance
# H1_wavelet-LLH_glrlm_ShortRunEmphasis
# H1_wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis
# H1_wavelet-LLH_glrlm_ShortRunLowGrayLevelEmphasis
# H1_wavelet-LLH_glszm_GrayLevelNonUniformity
# H1_wavelet-LLH_glszm_GrayLevelNonUniformityNormalized
# H1_wavelet-LLH_glszm_GrayLevelVariance
# H1_wavelet-LLH_glszm_HighGrayLevelZoneEmphasis
# H1_wavelet-LLH_glszm_LargeAreaEmphasis
# H1_wavelet-LLH_glszm_LargeAreaHighGrayLevelEmphasis
# H1_wavelet-LLH_glszm_LargeAreaLowGrayLevelEmphasis
# H1_wavelet-LLH_glszm_LowGrayLevelZoneEmphasis
# H1_wavelet-LLH_glszm_SizeZoneNonUniformity
# H1_wavelet-LLH_glszm_SizeZoneNonUniformityNormalized
# H1_wavelet-LLH_glszm_SmallAreaEmphasis
# H1_wavelet-LLH_glszm_SmallAreaHighGrayLevelEmphasis
# H1_wavelet-LLH_glszm_SmallAreaLowGrayLevelEmphasis
# H1_wavelet-LLH_glszm_ZoneEntropy
# H1_wavelet-LLH_glszm_ZonePercentage
# H1_wavelet-LLH_glszm_ZoneVariance
# H1_wavelet-LLH_ngtdm_Busyness
# H1_wavelet-LLH_ngtdm_Coarseness
# H1_wavelet-LLH_ngtdm_Complexity
# ...
# H3_wavelet-HLL_glrlm_LongRunHighGrayLevelEmphasis
# H3_wavelet-HLL_glrlm_LongRunLowGrayLevelEmphasis
# H3_wavelet-HLL_glrlm_LowGrayLevelRunEmphasis
# H3_wavelet-HLL_glrlm_RunEntropy
# H3_wavelet-HLL_glrlm_RunLengthNonUniformity
# H3_wavelet-HLL_glrlm_RunLengthNonUniformityNormalized
# H3_wavelet-HLL_glrlm_RunPercentage
# H3_wavelet-HLL_glrlm_RunVariance
# H3_wavelet-HLL_glrlm_ShortRunEmphasis
# H3_wavelet-HLL_glrlm_ShortRunHighGrayLevelEmphasis
# H3_wavelet-HLL_glrlm_ShortRunLowGrayLevelEmphasis
# H3_wavelet-HLL_glszm_GrayLevelNonUniformity
# H3_wavelet-HLL_glszm_GrayLevelNonUniformityNormalized
# H3_wavelet-HLL_glszm_GrayLevelVariance
# H3_wavelet-HLL_glszm_HighGrayLevelZoneEmphasis
# H3_wavelet-HLL_glszm_LargeAreaEmphasis
# H3_wavelet-HLL_glszm_LargeAreaHighGrayLevelEmphasis
# H3_wavelet-HLL_glszm_LargeAreaLowGrayLevelEmphasis
# H3_wavelet-HLL_glszm_LowGrayLevelZoneEmphasis
# H3_wavelet-HLL_glszm_SizeZoneNonUniformity
# H3_wavelet-HLL_glszm_SizeZoneNonUniformityNormalized
# H3_wavelet-HLL_glszm_SmallAreaEmphasis
# H3_wavelet-HLL_glszm_SmallAreaHighGrayLevelEmphasis
# H3_wavelet-HLL_glszm_SmallAreaLowGrayLevelEmphasis
# H3_wavelet-HLL_glszm_ZoneEntropy
# H3_wavelet-HLL_glszm_ZonePercentage
# H3_wavelet-HLL_glszm_ZoneVariance
# H3_wavelet-HLL_ngtdm_Busyness
# H3_wavelet-HLL_ngtdm_Coarseness
# H3_wavelet-HLL_ngtdm_Complexity
# H3_wavelet-HLL_ngtdm_Contrast
# H3_wavelet-HLL_ngtdm_Strength
# H3_wavelet-LHH_firstorder_10Percentile
# H3_wavelet-LHH_firstorder_90Percentile
# H3_wavelet-LHH_firstorder_Energy
# H3_wavelet-LHH_firstorder_Entropy
# H3_wavelet-LHH_firstorder_InterquartileRange
# H3_wavelet-LHH_firstorder_Kurtosis
# H3_wavelet-LHH_firstorder_Maximum
# H3_wavelet-LHH_firstorder_Mean
# H3_wavelet-LHH_firstorder_MeanAbsoluteDeviation
# H3_wavelet-LHH_firstorder_Median
# H3_wavelet-LHH_firstorder_Minimum
# H3_wavelet-LHH_firstorder_Range
# H3_wavelet-LHH_firstorder_RobustMeanAbsoluteDeviation
# H3_wavelet-LHH_firstorder_RootMeanSquared
# H3_wavelet-LHH_firstorder_Skewness
# H3_wavelet-LHH_firstorder_TotalEnergy
# H3_wavelet-LHH_firstorder_Uniformity
# H3_wavelet-LHH_firstorder_Variance
# H3_wavelet-LHH_glcm_Autocorrelation
# H3_wavelet-LHH_glcm_ClusterProminence
# H3_wavelet-LHH_glcm_ClusterShade
# H3_wavelet-LHH_glcm_ClusterTendency
# H3_wavelet-LHH_glcm_Contrast
# H3_wavelet-LHH_glcm_Correlation
# H3_wavelet-LHH_glcm_DifferenceAverage
# H3_wavelet-LHH_glcm_DifferenceEntropy
# H3_wavelet-LHH_glcm_DifferenceVariance
# H3_wavelet-LHH_glcm_Id
# H3_wavelet-LHH_glcm_Idm
# H3_wavelet-LHH_glcm_Idmn
# H3_wavelet-LHH_glcm_Idn
# H3_wavelet-LHH_glcm_Imc1
# H3_wavelet-LHH_glcm_Imc2
# H3_wavelet-LHH_glcm_InverseVariance
# H3_wavelet-LHH_glcm_JointAverage
# H3_wavelet-LHH_glcm_JointEnergy
# H3_wavelet-LHH_glcm_JointEntropy
# H3_wavelet-LHH_glcm_MCC
# H3_wavelet-LHH_glcm_MaximumProbability
# H3_wavelet-LHH_glcm_SumAverage
# H3_wavelet-LHH_glcm_SumEntropy
# H3_wavelet-LHH_glcm_SumSquares
# H3_wavelet-LHH_gldm_DependenceEntropy
# H3_wavelet-LHH_gldm_DependenceNonUniformity
# H3_wavelet-LHH_gldm_DependenceNonUniformityNormalized
# H3_wavelet-LHH_gldm_DependenceVariance
# H3_wavelet-LHH_gldm_GrayLevelNonUniformity
# H3_wavelet-LHH_gldm_GrayLevelVariance
# H3_wavelet-LHH_gldm_HighGrayLevelEmphasis
# H3_wavelet-LHH_gldm_LargeDependenceEmphasis
# H3_wavelet-LHH_gldm_LargeDependenceHighGrayLevelEmphasis
# H3_wavelet-LHH_gldm_LargeDependenceLowGrayLevelEmphasis
# H3_wavelet-LHH_gldm_LowGrayLevelEmphasis
# H3_wavelet-LHH_gldm_SmallDependenceEmphasis
# H3_wavelet-LHH_gldm_SmallDependenceHighGrayLevelEmphasis
# H3_wavelet-LHH_gldm_SmallDependenceLowGrayLevelEmphasis
# H3_wavelet-LHH_glrlm_GrayLevelNonUniformity
# H3_wavelet-LHH_glrlm_GrayLevelNonUniformityNormalized
# H3_wavelet-LHH_glrlm_GrayLevelVariance
# H3_wavelet-LHH_glrlm_HighGrayLevelRunEmphasis
# H3_wavelet-LHH_glrlm_LongRunEmphasis
# H3_wavelet-LHH_glrlm_LongRunHighGrayLevelEmphasis
# H3_wavelet-LHH_glrlm_LongRunLowGrayLevelEmphasis
# H3_wavelet-LHH_glrlm_LowGrayLevelRunEmphasis
# H3_wavelet-LHH_glrlm_RunEntropy
# H3_wavelet-LHH_glrlm_RunLengthNonUniformity
# H3_wavelet-LHH_glrlm_RunLengthNonUniformityNormalized
# H3_wavelet-LHH_glrlm_RunPercentage
# H3_wavelet-LHH_glrlm_RunVariance
# H3_wavelet-LHH_glrlm_ShortRunEmphasis
# H3_wavelet-LHH_glrlm_ShortRunHighGrayLevelEmphasis
# H3_wavelet-LHH_glrlm_ShortRunLowGrayLevelEmphasis
# H3_wavelet-LHH_glszm_GrayLevelNonUniformity
# H3_wavelet-LHH_glszm_GrayLevelNonUniformityNormalized
# H3_wavelet-LHH_glszm_GrayLevelVariance
# H3_wavelet-LHH_glszm_HighGrayLevelZoneEmphasis
# H3_wavelet-LHH_glszm_LargeAreaEmphasis
# H3_wavelet-LHH_glszm_LargeAreaHighGrayLevelEmphasis
# H3_wavelet-LHH_glszm_LargeAreaLowGrayLevelEmphasis
# H3_wavelet-LHH_glszm_LowGrayLevelZoneEmphasis
# H3_wavelet-LHH_glszm_SizeZoneNonUniformity
# H3_wavelet-LHH_glszm_SizeZoneNonUniformityNormalized
# H3_wavelet-LHH_glszm_SmallAreaEmphasis
# H3_wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis
# H3_wavelet-LHH_glszm_SmallAreaLowGrayLevelEmphasis
# H3_wavelet-LHH_glszm_ZoneEntropy
# H3_wavelet-LHH_glszm_ZonePercentage
# H3_wavelet-LHH_glszm_ZoneVariance
# H3_wavelet-LHH_ngtdm_Busyness
# H3_wavelet-LHH_ngtdm_Coarseness
# H3_wavelet-LHH_ngtdm_Complexity
# H3_wavelet-LHH_ngtdm_Contrast
# H3_wavelet-LHH_ngtdm_Strength
# H3_wavelet-LHL_firstorder_10Percentile
# H3_wavelet-LHL_firstorder_90Percentile
# H3_wavelet-LHL_firstorder_Energy
# H3_wavelet-LHL_firstorder_Entropy
# H3_wavelet-LHL_firstorder_InterquartileRange
# H3_wavelet-LHL_firstorder_Kurtosis
# H3_wavelet-LHL_firstorder_Maximum
# H3_wavelet-LHL_firstorder_Mean
# H3_wavelet-LHL_firstorder_MeanAbsoluteDeviation
# H3_wavelet-LHL_firstorder_Median
# H3_wavelet-LHL_firstorder_Minimum
# H3_wavelet-LHL_firstorder_Range
# H3_wavelet-LHL_firstorder_RobustMeanAbsoluteDeviation
# H3_wavelet-LHL_firstorder_RootMeanSquared
# H3_wavelet-LHL_firstorder_Skewness
# H3_wavelet-LHL_firstorder_TotalEnergy
# H3_wavelet-LHL_firstorder_Uniformity
# H3_wavelet-LHL_firstorder_Variance
# H3_wavelet-LHL_glcm_Autocorrelation
# H3_wavelet-LHL_glcm_ClusterProminence
# H3_wavelet-LHL_glcm_ClusterShade
# H3_wavelet-LHL_glcm_ClusterTendency
# H3_wavelet-LHL_glcm_Contrast
# H3_wavelet-LHL_glcm_Correlation
# H3_wavelet-LHL_glcm_DifferenceAverage
# H3_wavelet-LHL_glcm_DifferenceEntropy
# H3_wavelet-LHL_glcm_DifferenceVariance
# H3_wavelet-LHL_glcm_Id
# H3_wavelet-LHL_glcm_Idm
# H3_wavelet-LHL_glcm_Idmn
# H3_wavelet-LHL_glcm_Idn
# H3_wavelet-LHL_glcm_Imc1
# H3_wavelet-LHL_glcm_Imc2
# H3_wavelet-LHL_glcm_InverseVariance
# H3_wavelet-LHL_glcm_JointAverage
# H3_wavelet-LHL_glcm_JointEnergy
# H3_wavelet-LHL_glcm_JointEntropy
# H3_wavelet-LHL_glcm_MCC
# H3_wavelet-LHL_glcm_MaximumProbability
# H3_wavelet-LHL_glcm_SumAverage
# H3_wavelet-LHL_glcm_SumEntropy
# H3_wavelet-LHL_glcm_SumSquares
# H3_wavelet-LHL_gldm_DependenceEntropy
# H3_wavelet-LHL_gldm_DependenceNonUniformity
# H3_wavelet-LHL_gldm_DependenceNonUniformityNormalized
# H3_wavelet-LHL_gldm_DependenceVariance
# H3_wavelet-LHL_gldm_GrayLevelNonUniformity
# H3_wavelet-LHL_gldm_GrayLevelVariance
# H3_wavelet-LHL_gldm_HighGrayLevelEmphasis
# H3_wavelet-LHL_gldm_LargeDependenceEmphasis
# H3_wavelet-LHL_gldm_LargeDependenceHighGrayLevelEmphasis
# H3_wavelet-LHL_gldm_LargeDependenceLowGrayLevelEmphasis
# H3_wavelet-LHL_gldm_LowGrayLevelEmphasis
# H3_wavelet-LHL_gldm_SmallDependenceEmphasis
# H3_wavelet-LHL_gldm_SmallDependenceHighGrayLevelEmphasis
# H3_wavelet-LHL_gldm_SmallDependenceLowGrayLevelEmphasis
# H3_wavelet-LHL_glrlm_GrayLevelNonUniformity
# H3_wavelet-LHL_glrlm_GrayLevelNonUniformityNormalized
# H3_wavelet-LHL_glrlm_GrayLevelVariance
# H3_wavelet-LHL_glrlm_HighGrayLevelRunEmphasis
# H3_wavelet-LHL_glrlm_LongRunEmphasis
# H3_wavelet-LHL_glrlm_LongRunHighGrayLevelEmphasis
# H3_wavelet-LHL_glrlm_LongRunLowGrayLevelEmphasis
# H3_wavelet-LHL_glrlm_LowGrayLevelRunEmphasis
# H3_wavelet-LHL_glrlm_RunEntropy
# H3_wavelet-LHL_glrlm_RunLengthNonUniformity
# H3_wavelet-LHL_glrlm_RunLengthNonUniformityNormalized
# H3_wavelet-LHL_glrlm_RunPercentage
# H3_wavelet-LHL_glrlm_RunVariance
# H3_wavelet-LHL_glrlm_ShortRunEmphasis
# H3_wavelet-LHL_glrlm_ShortRunHighGrayLevelEmphasis
# H3_wavelet-LHL_glrlm_ShortRunLowGrayLevelEmphasis
# H3_wavelet-LHL_glszm_GrayLevelNonUniformity
# H3_wavelet-LHL_glszm_GrayLevelNonUniformityNormalized
# H3_wavelet-LHL_glszm_GrayLevelVariance
# H3_wavelet-LHL_glszm_HighGrayLevelZoneEmphasis
# H3_wavelet-LHL_glszm_LargeAreaEmphasis
# H3_wavelet-LHL_glszm_LargeAreaHighGrayLevelEmphasis
# H3_wavelet-LHL_glszm_LargeAreaLowGrayLevelEmphasis
# H3_wavelet-LHL_glszm_LowGrayLevelZoneEmphasis
# H3_wavelet-LHL_glszm_SizeZoneNonUniformity
# H3_wavelet-LHL_glszm_SizeZoneNonUniformityNormalized
# H3_wavelet-LHL_glszm_SmallAreaEmphasis
# H3_wavelet-LHL_glszm_SmallAreaHighGrayLevelEmphasis
# H3_wavelet-LHL_glszm_SmallAreaLowGrayLevelEmphasis
# H3_wavelet-LHL_glszm_ZoneEntropy
# H3_wavelet-LHL_glszm_ZonePercentage
# H3_wavelet-LHL_glszm_ZoneVariance
# H3_wavelet-LHL_ngtdm_Busyness
# H3_wavelet-LHL_ngtdm_Coarseness
# H3_wavelet-LHL_ngtdm_Complexity
# H3_wavelet-LHL_ngtdm_Contrast
# H3_wavelet-LHL_ngtdm_Strength
# H3_wavelet-LLH_firstorder_10Percentile
# H3_wavelet-LLH_firstorder_90Percentile
# H3_wavelet-LLH_firstorder_Energy
# H3_wavelet-LLH_firstorder_Entropy
# H3_wavelet-LLH_firstorder_InterquartileRange
# H3_wavelet-LLH_firstorder_Kurtosis
# H3_wavelet-LLH_firstorder_Maximum
# H3_wavelet-LLH_firstorder_Mean
# H3_wavelet-LLH_firstorder_MeanAbsoluteDeviation
# H3_wavelet-LLH_firstorder_Median
# H3_wavelet-LLH_firstorder_Minimum
# H3_wavelet-LLH_firstorder_Range
# H3_wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation
# H3_wavelet-LLH_firstorder_RootMeanSquared
# H3_wavelet-LLH_firstorder_Skewness
# H3_wavelet-LLH_firstorder_TotalEnergy
# H3_wavelet-LLH_firstorder_Uniformity
# H3_wavelet-LLH_firstorder_Variance
# H3_wavelet-LLH_glcm_Autocorrelation
# H3_wavelet-LLH_glcm_ClusterProminence
# H3_wavelet-LLH_glcm_ClusterShade
# H3_wavelet-LLH_glcm_ClusterTendency
# H3_wavelet-LLH_glcm_Contrast
# H3_wavelet-LLH_glcm_Correlation
# H3_wavelet-LLH_glcm_DifferenceAverage
# H3_wavelet-LLH_glcm_DifferenceEntropy
# H3_wavelet-LLH_glcm_DifferenceVariance
# H3_wavelet-LLH_glcm_Id
# H3_wavelet-LLH_glcm_Idm
# H3_wavelet-LLH_glcm_Idmn
# H3_wavelet-LLH_glcm_Idn
# H3_wavelet-LLH_glcm_Imc1
# H3_wavelet-LLH_glcm_Imc2
# H3_wavelet-LLH_glcm_InverseVariance
# H3_wavelet-LLH_glcm_JointAverage
# H3_wavelet-LLH_glcm_JointEnergy
# H3_wavelet-LLH_glcm_JointEntropy
# H3_wavelet-LLH_glcm_MCC
# H3_wavelet-LLH_glcm_MaximumProbability
# H3_wavelet-LLH_glcm_SumAverage
# H3_wavelet-LLH_glcm_SumEntropy
# H3_wavelet-LLH_glcm_SumSquares
# H3_wavelet-LLH_gldm_DependenceEntropy
# H3_wavelet-LLH_gldm_DependenceNonUniformity
# H3_wavelet-LLH_gldm_DependenceNonUniformityNormalized
# H3_wavelet-LLH_gldm_DependenceVariance
# H3_wavelet-LLH_gldm_GrayLevelNonUniformity
# H3_wavelet-LLH_gldm_GrayLevelVariance
# H3_wavelet-LLH_gldm_HighGrayLevelEmphasis
# H3_wavelet-LLH_gldm_LargeDependenceEmphasis
# H3_wavelet-LLH_gldm_LargeDependenceHighGrayLevelEmphasis
# H3_wavelet-LLH_gldm_LargeDependenceLowGrayLevelEmphasis
# H3_wavelet-LLH_gldm_LowGrayLevelEmphasis
# H3_wavelet-LLH_gldm_SmallDependenceEmphasis
# H3_wavelet-LLH_gldm_SmallDependenceHighGrayLevelEmphasis
# H3_wavelet-LLH_gldm_SmallDependenceLowGrayLevelEmphasis
# H3_wavelet-LLH_glrlm_GrayLevelNonUniformity
# H3_wavelet-LLH_glrlm_GrayLevelNonUniformityNormalized
# H3_wavelet-LLH_glrlm_GrayLevelVariance
# H3_wavelet-LLH_glrlm_HighGrayLevelRunEmphasis
# H3_wavelet-LLH_glrlm_LongRunEmphasis
# H3_wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis
# H3_wavelet-LLH_glrlm_LongRunLowGrayLevelEmphasis
# H3_wavelet-LLH_glrlm_LowGrayLevelRunEmphasis
# H3_wavelet-LLH_glrlm_RunEntropy
# H3_wavelet-LLH_glrlm_RunLengthNonUniformity
# H3_wavelet-LLH_glrlm_RunLengthNonUniformityNormalized
# H3_wavelet-LLH_glrlm_RunPercentage
# H3_wavelet-LLH_glrlm_RunVariance
# H3_wavelet-LLH_glrlm_ShortRunEmphasis
# H3_wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis
# H3_wavelet-LLH_glrlm_ShortRunLowGrayLevelEmphasis
# H3_wavelet-LLH_glszm_GrayLevelNonUniformity
# H3_wavelet-LLH_glszm_GrayLevelNonUniformityNormalized
# H3_wavelet-LLH_glszm_GrayLevelVariance
# H3_wavelet-LLH_glszm_HighGrayLevelZoneEmphasis
# H3_wavelet-LLH_glszm_LargeAreaEmphasis
# H3_wavelet-LLH_glszm_LargeAreaHighGrayLevelEmphasis
# H3_wavelet-LLH_glszm_LargeAreaLowGrayLevelEmphasis
# H3_wavelet-LLH_glszm_LowGrayLevelZoneEmphasis
# H3_wavelet-LLH_glszm_SizeZoneNonUniformity
# H3_wavelet-LLH_glszm_SizeZoneNonUniformityNormalized
# H3_wavelet-LLH_glszm_SmallAreaEmphasis
# H3_wavelet-LLH_glszm_SmallAreaHighGrayLevelEmphasis
# H3_wavelet-LLH_glszm_SmallAreaLowGrayLevelEmphasis
# H3_wavelet-LLH_glszm_ZoneEntropy
# H3_wavelet-LLH_glszm_ZonePercentage
# H3_wavelet-LLH_glszm_ZoneVariance
# H3_wavelet-LLH_ngtdm_Busyness
# H3_wavelet-LLH_ngtdm_Coarseness
# H3_wavelet-LLH_ngtdm_Complexity
# H3_wavelet-LLH_ngtdm_Contrast
# H3_wavelet-LLH_ngtdm_Strength
# H3_wavelet-LLL_firstorder_10Percentile
# H3_wavelet-LLL_firstorder_90Percentile
# H3_wavelet-LLL_firstorder_Energy
# H3_wavelet-LLL_firstorder_Entropy
# H3_wavelet-LLL_firstorder_InterquartileRange
# H3_wavelet-LLL_firstorder_Kurtosis
# H3_wavelet-LLL_firstorder_Maximum
# H3_wavelet-LLL_firstorder_Mean
# H3_wavelet-LLL_firstorder_MeanAbsoluteDeviation
# H3_wavelet-LLL_firstorder_Median
# H3_wavelet-LLL_firstorder_Minimum
# H3_wavelet-LLL_firstorder_Range
# H3_wavelet-LLL_firstorder_RobustMeanAbsoluteDeviation
# H3_wavelet-LLL_firstorder_RootMeanSquared
# H3_wavelet-LLL_firstorder_Skewness
# H3_wavelet-LLL_firstorder_TotalEnergy
# H3_wavelet-LLL_firstorder_Uniformity
# H3_wavelet-LLL_firstorder_Variance
# H3_wavelet-LLL_glcm_Autocorrelation
# H3_wavelet-LLL_glcm_ClusterProminence
# H3_wavelet-LLL_glcm_ClusterShade
# H3_wavelet-LLL_glcm_ClusterTendency
# H3_wavelet-LLL_glcm_Contrast
# H3_wavelet-LLL_glcm_Correlation
# H3_wavelet-LLL_glcm_DifferenceAverage
# H3_wavelet-LLL_glcm_DifferenceEntropy
# H3_wavelet-LLL_glcm_DifferenceVariance
# H3_wavelet-LLL_glcm_Id
# H3_wavelet-LLL_glcm_Idm
# H3_wavelet-LLL_glcm_Idmn
# H3_wavelet-LLL_glcm_Idn
# H3_wavelet-LLL_glcm_Imc1
# H3_wavelet-LLL_glcm_Imc2
# H3_wavelet-LLL_glcm_InverseVariance
# H3_wavelet-LLL_glcm_JointAverage
# H3_wavelet-LLL_glcm_JointEnergy
# H3_wavelet-LLL_glcm_JointEntropy
# H3_wavelet-LLL_glcm_MCC
# H3_wavelet-LLL_glcm_MaximumProbability
# H3_wavelet-LLL_glcm_SumAverage
# H3_wavelet-LLL_glcm_SumEntropy
# H3_wavelet-LLL_glcm_SumSquares
# H3_wavelet-LLL_gldm_DependenceEntropy
# H3_wavelet-LLL_gldm_DependenceNonUniformity
# H3_wavelet-LLL_gldm_DependenceNonUniformityNormalized
# H3_wavelet-LLL_gldm_DependenceVariance
# H3_wavelet-LLL_gldm_GrayLevelNonUniformity
# H3_wavelet-LLL_gldm_GrayLevelVariance
# H3_wavelet-LLL_gldm_HighGrayLevelEmphasis
# H3_wavelet-LLL_gldm_LargeDependenceEmphasis
# H3_wavelet-LLL_gldm_LargeDependenceHighGrayLevelEmphasis
# H3_wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis
# H3_wavelet-LLL_gldm_LowGrayLevelEmphasis
# H3_wavelet-LLL_gldm_SmallDependenceEmphasis
# H3_wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis
# H3_wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis
# H3_wavelet-LLL_glrlm_GrayLevelNonUniformity
# H3_wavelet-LLL_glrlm_GrayLevelNonUniformityNormalized
# H3_wavelet-LLL_glrlm_GrayLevelVariance
# H3_wavelet-LLL_glrlm_HighGrayLevelRunEmphasis
# H3_wavelet-LLL_glrlm_LongRunEmphasis
# H3_wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis
# H3_wavelet-LLL_glrlm_LongRunLowGrayLevelEmphasis
# H3_wavelet-LLL_glrlm_LowGrayLevelRunEmphasis
# H3_wavelet-LLL_glrlm_RunEntropy
# H3_wavelet-LLL_glrlm_RunLengthNonUniformity
# H3_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized
# H3_wavelet-LLL_glrlm_RunPercentage
# H3_wavelet-LLL_glrlm_RunVariance
# H3_wavelet-LLL_glrlm_ShortRunEmphasis
# H3_wavelet-LLL_glrlm_ShortRunHighGrayLevelEmphasis
# H3_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis
# H3_wavelet-LLL_glszm_GrayLevelNonUniformity
# H3_wavelet-LLL_glszm_GrayLevelNonUniformityNormalized
# H3_wavelet-LLL_glszm_GrayLevelVariance
# H3_wavelet-LLL_glszm_HighGrayLevelZoneEmphasis
# H3_wavelet-LLL_glszm_LargeAreaEmphasis
# H3_wavelet-LLL_glszm_LargeAreaHighGrayLevelEmphasis
# H3_wavelet-LLL_glszm_LargeAreaLowGrayLevelEmphasis
# H3_wavelet-LLL_glszm_LowGrayLevelZoneEmphasis
# H3_wavelet-LLL_glszm_SizeZoneNonUniformity
# H3_wavelet-LLL_glszm_SizeZoneNonUniformityNormalized
# H3_wavelet-LLL_glszm_SmallAreaEmphasis
# H3_wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis
# H3_wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis
# H3_wavelet-LLL_glszm_ZoneEntropy
# H3_wavelet-LLL_glszm_ZonePercentage
# H3_wavelet-LLL_glszm_ZoneVariance
# H3_wavelet-LLL_ngtdm_Busyness
# H3_wavelet-LLL_ngtdm_Coarseness
# H3_wavelet-LLL_ngtdm_Complexity
# H3_wavelet-LLL_ngtdm_Contrast
# H3_wavelet-LLL_ngtdm_Strength
# 筛选后剩下的特征数：1863个

# %%
print(columns_index)
# Out:
# ['H1_diagnostics_Image-interpolated_Maximum', 'H1_diagnostics_Image-interpolated_Mean', 'H1_diagnostics_Image-interpolated_Minimum', 'H1_diagnostics_Mask-interpolated_Maximum', 'H1_diagnostics_Mask-interpolated_Mean', 'H1_diagnostics_Mask-interpolated_Minimum', 'H1_diagnostics_Mask-interpolated_VolumeNum', 'H1_diagnostics_Mask-interpolated_VoxelNum', 'H1_diagnostics_Mask-original_VolumeNum', 'H1_diagnostics_Mask-original_VoxelNum', 'H1_log-sigma-1-0-mm-3D_firstorder_10Percentile', 'H1_log-sigma-1-0-mm-3D_firstorder_90Percentile', 'H1_log-sigma-1-0-mm-3D_firstorder_Entropy', 'H1_log-sigma-1-0-mm-3D_firstorder_InterquartileRange', 'H1_log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'H1_log-sigma-1-0-mm-3D_firstorder_Maximum', 'H1_log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation', 'H1_log-sigma-1-0-mm-3D_firstorder_Minimum', 'H1_log-sigma-1-0-mm-3D_firstorder_Range', 'H1_log-sigma-1-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation', 'H1_log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'H1_log-sigma-1-0-mm-3D_firstorder_Uniformity', 'H1_log-sigma-1-0-mm-3D_firstorder_Variance', 'H1_log-sigma-1-0-mm-3D_glcm_Autocorrelation', 'H1_log-sigma-1-0-mm-3D_glcm_ClusterTendency', 'H1_log-sigma-1-0-mm-3D_glcm_Contrast', 'H1_log-sigma-1-0-mm-3D_glcm_Correlation', 'H1_log-sigma-1-0-mm-3D_glcm_DifferenceAverage', 'H1_log-sigma-1-0-mm-3D_glcm_DifferenceEntropy', 'H1_log-sigma-1-0-mm-3D_glcm_DifferenceVariance', 'H1_log-sigma-1-0-mm-3D_glcm_Id', 'H1_log-sigma-1-0-mm-3D_glcm_Idm', 'H1_log-sigma-1-0-mm-3D_glcm_Idmn', 'H1_log-sigma-1-0-mm-3D_glcm_Idn', 'H1_log-sigma-1-0-mm-3D_glcm_Imc1', 'H1_log-sigma-1-0-mm-3D_glcm_Imc2', 'H1_log-sigma-1-0-mm-3D_glcm_InverseVariance', 'H1_log-sigma-1-0-mm-3D_glcm_JointAverage', 'H1_log-sigma-1-0-mm-3D_glcm_JointEnergy', 'H1_log-sigma-1-0-mm-3D_glcm_JointEntropy', 'H1_log-sigma-1-0-mm-3D_glcm_MCC', 'H1_log-sigma-1-0-mm-3D_glcm_MaximumProbability', 'H1_log-sigma-1-0-mm-3D_glcm_SumAverage', 'H1_log-sigma-1-0-mm-3D_glcm_SumEntropy', 'H1_log-sigma-1-0-mm-3D_glcm_SumSquares', 'H1_log-sigma-1-0-mm-3D_gldm_DependenceEntropy', 'H1_log-sigma-1-0-mm-3D_gldm_DependenceNonUniformity', 'H1_log-sigma-1-0-mm-3D_gldm_DependenceNonUniformityNormalized', 'H1_log-sigma-1-0-mm-3D_gldm_DependenceVariance', 'H1_log-sigma-1-0-mm-3D_gldm_GrayLevelNonUniformity', 'H1_log-sigma-1-0-mm-3D_gldm_GrayLevelVariance', 'H1_log-sigma-1-0-mm-3D_gldm_HighGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_gldm_LargeDependenceEmphasis', 'H1_log-sigma-1-0-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_gldm_LowGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformity', 'H1_log-sigma-1-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized', 'H1_log-sigma-1-0-mm-3D_glrlm_GrayLevelVariance', 'H1_log-sigma-1-0-mm-3D_glrlm_HighGrayLevelRunEmphasis', 'H1_log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_glrlm_LowGrayLevelRunEmphasis', 'H1_log-sigma-1-0-mm-3D_glrlm_RunEntropy', 'H1_log-sigma-1-0-mm-3D_glrlm_RunLengthNonUniformity', 'H1_log-sigma-1-0-mm-3D_glrlm_RunPercentage', 'H1_log-sigma-1-0-mm-3D_glrlm_RunVariance', 'H1_log-sigma-1-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis', 'H1_log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformity', 'H1_log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'H1_log-sigma-1-0-mm-3D_glszm_GrayLevelVariance', 'H1_log-sigma-1-0-mm-3D_glszm_HighGrayLevelZoneEmphasis', 'H1_log-sigma-1-0-mm-3D_glszm_LowGrayLevelZoneEmphasis', 'H1_log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformity', 'H1_log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformityNormalized', 'H1_log-sigma-1-0-mm-3D_glszm_SmallAreaEmphasis', 'H1_log-sigma-1-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis', 'H1_ ...

# %%
columns_index.remove('*diagnostics_Image-original_Maximum')

# %%
from sklearn.linear_model import Lasso

# 标准化数据
scaler = StandardScaler()
# columns_index.remove('diagnostics_Image-original_Maximum')
X_train_scaled = scaler.fit_transform(X_train.loc[:, columns_index])

alpha_lasso = 10**np.linspace(-3,1,100)
lasso = Lasso()
coefs_lasso = []

for i in alpha_lasso:
    lasso.set_params(alpha = i)
    lasso.fit(X_train_scaled, y_train)
    coefs_lasso.append(lasso.coef_)

plt.figure(figsize=(12,10))
ax = plt.gca()
ax.plot(alpha_lasso, coefs_lasso)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights: scaled coefficients')
plt.title('Lasso regression coefficients Vs. alpha')
# plt.legend(y)
plt.show()

# %%
# coef = pd.Series(Lasso.coef_, index=columns_index)
# print(coef[coef !=0])

# %%
#再把特征值数据和标签数据分开
x = X_train.loc[:,columns_index]
y = y_train
#先保存X的列名
columnNames = x.columns

lassoCV_x = x.astype(np.float32)#把x数据转换成np.float格式
lassoCV_y = y

standardscaler = StandardScaler()
lassoCV_x = standardscaler.fit_transform(lassoCV_x)#对x进行均值-标准差归一化
lassoCV_x = pd.DataFrame(lassoCV_x,columns=columnNames)#转 DataFrame 格式

# 形成5为底的指数函数
# 5**（-3） ~  5**（-2）
alpha_range = np.logspace(-4,0,500,base=5)
#alpha_range在这个参数范围里挑出aplpha进行训练，cv是把数据集分5分，进行交叉验证，max_iter是训练1000轮
lassoCV_model = LassoCV(alphas=alpha_range,cv=5,max_iter=1000)
#进行训练
lassoCV_model.fit(lassoCV_x,lassoCV_y)

#打印训练找出来的入值
print(lassoCV_model.alpha_)
# print("Coefficient of the model:{}".format(lassoCV_model.coef_) )
# print("intercept of the model:{}".format(lassoCV_model.intercept_))

coef = pd.Series(lassoCV_model.coef_, index=columnNames)
print("从原来{}个特征，筛选剩下{}个".format(len(columnNames),sum(coef !=0)))
print("分别是以下特征")
print(coef[coef !=0])
index = coef[coef !=0].index
lassoCV_x = lassoCV_x[index]
# lassoCV_x.head()
# Out:
# 0.027338362340260356
# 从原来1863个特征，筛选剩下34个
# 分别是以下特征
# H1_log-sigma-1-0-mm-3D_glcm_Imc1                                  -0.042031
# H1_log-sigma-1-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis        -0.000203
# H1_log-sigma-1-0-mm-3D_ngtdm_Strength                             -0.006703
# H1_log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis                     0.002430
# H1_log-sigma-5-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis        0.002793
# H1_original_glrlm_LowGrayLevelRunEmphasis                         -0.006262
# H1_original_glrlm_ShortRunLowGrayLevelEmphasis                    -0.002294
# H1_original_glszm_LowGrayLevelZoneEmphasis                        -0.021230
# H1_original_glszm_ZoneEntropy                                      0.018819
# H1_wavelet-HLH_firstorder_Skewness                                 0.009527
# H1_wavelet-HLH_glcm_InverseVariance                               -0.020555
# H1_wavelet-HLL_ngtdm_Strength                                     -0.001881
# H1_wavelet-LLH_gldm_LargeDependenceLowGrayLevelEmphasis           -0.004323
# H1_wavelet-LLH_ngtdm_Contrast                                     -0.007472
# H1_wavelet-LLL_glrlm_RunVariance                                  -0.012530
# H1_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis                 -0.034037
# H1_wavelet-LLL_ngtdm_Strength                                     -0.013683
# H2_log-sigma-1-0-mm-3D_glszm_LowGrayLevelZoneEmphasis             -0.074103
# H2_log-sigma-3-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis         0.001073
# H2_log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis                     0.003471
# H2_log-sigma-5-0-mm-3D_glcm_Idn                                   -0.004438
# H2_log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized      -0.030866
# H2_original_shape_Sphericity                                      -0.001122
# H2_wavelet-HHH_glcm_InverseVariance                               -0.001619
# H2_wavelet-HHH_glszm_ZoneEntropy                                   0.011919
# H2_wavelet-HLH_glszm_SmallAreaLowGrayLevelEmphasis                -0.011862
# H2_wavelet-HLL_glcm_Correlation                                    0.021357
# H2_wavelet-LHH_glcm_Imc1                                          -0.002015
# H2_wavelet-LHL_gldm_LargeDependenceLowGrayLevelEmphasis           -0.001054
# H2_wavelet-LHL_glszm_SmallAreaEmphasis                             0.003715
# H2_wavelet-LHL_ngtdm_Strength                                     -0.008631
# H3_log-sigma-1-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis   -0.000646
# H3_log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis          0.019816
# H3_log-sigma-1-0-mm-3D_glrlm_LowGrayLevelRunEmphasis              -0.005768
# dtype: float32

# %%
#绘制特征相关系数热力图
import seaborn as sns

# 根据相关性筛选
# corr_matix=lassoCV_x.corr()
# # m=~(corr_matix.mask(np.eye(len(corr_matix),dtype=bool)).abs()>0.75).any()
# # n=(corr_matix.mask(np.eye(len(corr_matix),dtype=bool)).abs()>0.75).any()
# # raw=corr_matix.loc[m,m]
# # raw_n=corr_matix.loc[n,n]
# # raw_n
# def count_high_corr(matirx, high_corr, threshold=0.5):
#     for i in range(matirx.shape[0]):
#         np_raw=np.array(matirx.iloc[i,:])
#         result=np.argwhere(np.abs(np_raw)>threshold).tolist()
#         result=[int(i[0]) for i in result]
#         high_corr[i]=len(result)
#     return high_corr
#
# hash_map=np.array(range(corr_matix.shape[0]))
# Flag=True
# high_corr=np.ones_like(hash_map)
# # corr_matix=np.array(corr_matix)
# r_list=[]
# while Flag:
#     origin_high_count=count_high_corr(corr_matix,high_corr)
#     # print(corr_matix.shape)
#     result=np.argmax(origin_high_count)
#     depend=np.max(origin_high_count)
#     if depend==1:
#         Flag=False
#         break
#     r_list.append(result)
#     # print(result)
#     high_corr[result]=0
#     # print(high_corr)
#     corr_matix.iloc[result,:]=0
#     corr_matix.iloc[:,result]=0
#     # print(corr_matix.shape)
#     # corr_matix.head()
#
# hash_map=np.delete(hash_map,r_list)
# corr_matix=lassoCV_x.corr().iloc[hash_map,hash_map]

# 画出热力图
f, ax= plt.subplots(figsize = (10, 10))
sns.heatmap(lassoCV_x.corr(),cmap='rainbow',annot=True,annot_kws={'size':7,'weight':'bold', },ax=ax)#绘制混淆矩阵
ax.set_xticklabels(ax.get_xticklabels(), rotation=45,va="top",ha="right")
ax.set_yticklabels(ax.get_yticklabels(), rotation=45)
plt.show()

# %%
# index=corr_matix.index
# lassoCV_x = lassoCV_x[index]
# coef = coef.loc[index]
# print(coef.shape)

# %%
weight = coef[np.abs(coef)>0.03].to_dict()

# %%
#画一个特征系数的柱状图
weight = coef[np.abs(coef)>0.01].to_dict()
#根据值大小排列一下
weight = dict(sorted(weight.items(),key=lambda x:x[1],reverse=False))
plt.figure(figsize=(8,6))#设置画布的尺寸
plt.title('characters classification weight',fontsize=15)#标题，并设定字号大小
plt.xlabel(u'weighted value',fontsize=14)#设置x轴，并设定字号大小
plt.ylabel(u'feature')
plt.barh(range(len(weight.values())), list(weight.values()),tick_label = list(weight.keys()),alpha=0.6, facecolor = 'blue', edgecolor = 'black', label='feature weight')
plt.xlim([-0.1,0.1])
plt.legend(loc=4)#图例展示位置，数字代表第几象限
plt.show()
pd_weight=pd.DataFrame(coef[np.abs(coef)>0.01])
pd_weight=pd_weight.sort_values(by=0)
pd_weight
# Out:
#                                                            0
# H2_log-sigma-1-0-mm-3D_glszm_LowGrayLevelZoneEm... -0.074103
# H1_log-sigma-1-0-mm-3D_glcm_Imc1                   -0.042031
# H1_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis  -0.034037
# H2_log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniform... -0.030866
# H1_original_glszm_LowGrayLevelZoneEmphasis         -0.021230
# H1_wavelet-HLH_glcm_InverseVariance                -0.020555
# H1_wavelet-LLL_ngtdm_Strength                      -0.013683
# H1_wavelet-LLL_glrlm_RunVariance                   -0.012530
# H2_wavelet-HLH_glszm_SmallAreaLowGrayLevelEmphasis -0.011862
# H2_wavelet-HHH_glszm_ZoneEntropy                    0.011919
# H1_original_glszm_ZoneEntropy                       0.018819
# H3_log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLev...  0.019816
# H2_wavelet-HLL_glcm_Correlation                     0.021357

# %%
#绘制误差棒图
MSEs = lassoCV_model.mse_path_
mse = list()
std = list()
for m in MSEs:
    mse.append(np.mean(m))
    std.append(np.std(m))

plt.figure(figsize=(8,6))
plt.errorbar(lassoCV_model.alphas_, mse, std,fmt='o:',ecolor='lightblue',
			elinewidth=3,ms=5,mfc='wheat',mec='salmon',capsize=3)
plt.axvline(lassoCV_model.alpha_, color='red', ls='--')
plt.title('Errorbar')
plt.xlabel('Lambda')
plt.ylabel('MSE')
plt.show()

# %%
#再把特征值数据和标签数据分开
x = X_train.loc[:,columns_index]
y = y_train
#先保存X的列名
columnNames = x.columns
lassoCV_x = x.astype(np.float32)#把x数据转换成np.float格式
lassoCV_y = y
lassoCV_x = standardscaler.transform(lassoCV_x)#对x进行均值-标准差归一化
lassoCV_x = pd.DataFrame(lassoCV_x,columns=columnNames)#转 DataFrame 格式
coefs = lassoCV_model.path(lassoCV_x,lassoCV_y, alphas=alpha_range, max_iter=1000)[1].T
plt.plot(lassoCV_model.alphas,coefs,'-')
plt.axvline(lassoCV_model.alpha_, color='red', ls='--')
plt.xlabel('Lambda')
plt.ylabel('coef')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.inspection import DecisionBoundaryDisplay

# %%
from sklearn.model_selection import train_test_split #分割训练集和验证集
from sklearn.ensemble import RandomForestClassifier #导入随机森林分类器
import joblib #用来保存 sklearn 训练好的模型
#把数据分成训练集和验证集，7：3比例
index_ = pd_weight.index
rforest_x = x[index_]
rforest_y = y
standardscaler = StandardScaler()
rforest_x = standardscaler.fit_transform(rforest_x)#对x进行均值-标准差归一化
x1_train,x1_test, y1_train, y1_test = train_test_split(rforest_x,rforest_y,test_size=0.2, stratify=y, random_state=44)
seed=4
model_forest = RandomForestClassifier(n_estimators=200,max_depth=13,max_features=1,random_state=seed).fit(x1_train,y1_train)
# model_forest = SVC(kernel="linear", C=0.025,probability=True).fit(x1_train,y1_train)
# model_forest = MLPClassifier(alpha=0.1, max_iter=1000).fit(x1_train,y1_train)
score = model_forest.score(x1_test, y1_test)
print("在验证集上的准确率：{}".format(score))
#把随机森林的模型保存下来
model_path='./model'
model_name = 'in_sub_rf0827.model'
if not os.path.exists(model_path):
    os.makedirs(model_path)
joblib.dump(model_forest, model_path+'/'+model_name)
# Out:
# 在验证集上的准确率：0.82
# ['./model/in_sub_rf0827.model']

# %%
from tabpfn import TabPFNClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline  # 必须使用imblearn的Pipeline
from sklearn.model_selection import cross_val_score

clf = TabPFNClassifier(
    random_state = 3407,     
    softmax_temperature=0.8,                # 提高预测锐度
    balance_probabilities=True, 
    memory_saving_mode=True,    
    device='cuda'
)  # 关键改动：添加 device='cuda' 参数

# model_forest = clf.fit(x1_train,y1_train)
model = Pipeline([
    ('sampler', SMOTE(sampling_strategy=0.9, random_state=1028)),  # 自动平衡至多数类数量
    ('classifier', clf)  # 同步启用权重保障
])
# model.fit(x1_train,y1_train)
# score = model.score(x1_test, y1_test)
scores = cross_val_score(model, rforest_x, rforest_y, cv=10, scoring='accuracy')
print("在验证集上的准确率：{}".format(scores.mean()))
model.fit(rforest_x, rforest_y)
#把随机森林的模型保存下来
model_path=r'E:\liuzhou_breastcancer\model'
model_name = 'in_sub_tabpfn0827.model'
if not os.path.exists(model_path):
    os.makedirs(model_path)
joblib.dump(model, model_path+'/'+model_name)
# Out:
# 在验证集上的准确率：0.8232244897959184
# ['E:\\liuzhou_breastcancer\\model/in_sub_tabpfn0827.model']

# %%
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from tabpfn import TabPFNClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline  # 必须使用imblearn的Pipeline
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, cross_validate

N_REPEATS = 10  # 重复次数
N_SPLITS = 10   # 每次的折数

clf = TabPFNClassifier(
    random_state = 3407,     
    softmax_temperature=0.8,                # 提高预测锐度
    balance_probabilities=True, 
    memory_saving_mode=True,    
    device='cuda'
)  # 关键改动：添加 device='cuda' 参数

# model_forest = clf.fit(x1_train,y1_train)
model = Pipeline([
    ('sampler', SMOTE(sampling_strategy=0.9, random_state=114514)),  # 自动平衡至多数类数量
    ('classifier', clf)  # 同步启用权重保障
])
# model.fit(x1_train,y1_train)
# score = model.score(x1_test, y1_test)

cv = RepeatedStratifiedKFold(
    n_splits=N_SPLITS,
    n_repeats=N_REPEATS,
    random_state=1028
)

# 评分函数，定义需要计算的指标
scoring = {
    'accuracy': 'accuracy',
    'sensitivity': make_scorer(recall_score),  # 召回率 (Sensitivity)
    'specificity': make_scorer(recall_score, pos_label=0),  # 特异度 (Specificity)，正类为0
    'precision': 'precision',
    'f1': 'f1',
    'auc': 'roc_auc'
}

# 使用cross_validate计算多个评分指标
scores = cross_validate(model, rforest_x, rforest_y, cv=cv, scoring=scoring)

# 打印交叉验证结果
print(f"完成 {N_REPEATS} 次 {N_SPLITS} 折交叉验证")
print("平均准确率: {:.3f} ± {:.3f}".format(np.mean(scores['test_accuracy']), np.std(scores['test_accuracy'])))
print("平均敏感性 (Sensitivity): {:.3f} ± {:.3f}".format(np.mean(scores['test_sensitivity']), np.std(scores['test_sensitivity'])))
print("平均特异性 (Specificity): {:.3f} ± {:.3f}".format(np.mean(scores['test_specificity']), np.std(scores['test_specificity'])))
print("平均精度 (Precision): {:.3f} ± {:.3f}".format(np.mean(scores['test_precision']), np.std(scores['test_precision'])))
print("平均F1分数: {:.3f} ± {:.3f}".format(np.mean(scores['test_f1']), np.std(scores['test_f1'])))
print("平均AUC: {:.3f} ± {:.3f}".format(np.mean(scores['test_auc']), np.std(scores['test_auc'])))

# 将所有的交叉验证结果保存为DataFrame
df_scores = pd.DataFrame({
    'repeat_id': np.repeat(np.arange(N_REPEATS), N_SPLITS),
    'fold_id': np.tile(np.arange(N_SPLITS), N_REPEATS),
    'accuracy': scores['test_accuracy'],
    'sensitivity': scores['test_sensitivity'],
    'specificity': scores['test_specificity'],
    'precision': scores['test_precision'],
    'f1': scores['test_f1'],
    'auc': scores['test_auc']
})

# 保存为CSV（添加元数据标题）
result_path = r'E:\liuzhou_breastcancer\eval_results'
csv_path = os.path.join(result_path, 'in_sub_val_results_0827.csv')
df_scores.to_csv(csv_path, index=False, header=[
    'RepeatID', 'FoldID', 'Accuracy', 'Sensitivity', 'Specificity', 'Precision', 'F1', 'AUC'
])


model.fit(rforest_x, rforest_y)
#把随机森林的模型保存下来
model_path=r'E:\liuzhou_breastcancer\model'
model_name = 'in_sub_tabpfn0827.model'
if not os.path.exists(model_path):
    os.makedirs(model_path)
joblib.dump(model, model_path+'/'+model_name)
# Out:
# 完成 10 次 10 折交叉验证
# 平均准确率: 0.795 ± 0.052
# 平均敏感性 (Sensitivity): 0.875 ± 0.062
# 平均特异性 (Specificity): 0.589 ± 0.128
# 平均精度 (Precision): 0.848 ± 0.040
# 平均F1分数: 0.860 ± 0.038
# 平均AUC: 0.821 ± 0.068
# ['E:\\liuzhou_breastcancer\\model/in_sub_tabpfn0827.model']

# %%
import joblib
from sklearn.metrics import classification_report, confusion_matrix
index = pd_weight.index
x_test_data = pd.DataFrame(X_test.loc[:,index])

columnNames = x_test_data.columns
x_test_data = x_test_data.astype(np.float32)

x_test_data = standardscaler.transform(x_test_data) #均值-标准差归一化
x_test_data = pd.DataFrame(x_test_data,columns=columnNames)
y_test_data = pd.DataFrame(y_test)

print("测试集一共有{}行特征数据，{}列不同特征".format(len(x_test_data),x_test_data.shape[1]))
#加载保存后的模型，然后进行预测


model_forest = joblib.load(model_path+'/'+model_name) #这是自己训练模型，记得替换自己的。
score = model_forest.score(x_test_data, y_test_data)
print("在测试集上的准确率：{}".format(score))

# 计算其他评估指标
# 分类报告：包括 Precision, Recall (Sensitivity), F1-score
y_pred = model_forest.predict(x_test_data)
print("\n分类报告：")
print(classification_report(y_test_data, y_pred))

precision = precision_score(y_test_data, y_pred)
recall = recall_score(y_test_data, y_pred)
f1 = f1_score(y_test_data, y_pred)
# 混淆矩阵：用于计算 Specificity 和 Sensitivity
conf_matrix = confusion_matrix(y_test_data, y_pred)
tn, fp, fn, tp = conf_matrix.ravel()

# Sensitivity（召回率） = TP / (TP + FN)
sensitivity = tp / (tp + fn)
# Specificity = TN / (TN + FP)
specificity = tn / (tn + fp)

# AUC (ROC曲线下的面积)
y_prob = model_forest.predict_proba(x_test_data)[:, 1]  # 获取正类的概率
auc_score = roc_auc_score(y_test_data, y_prob)

# 输出结果
print("\n整体结果:")
print(f"Sensitivity (召回率): {sensitivity:.4f}")
print(f"Specificity (特异性): {specificity:.4f}")
print(f"Precision (精确率): {precision:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"AUC: {auc_score:.4f}")

# 创建一个包含实际类别和预测概率的 DataFrame
result_df = pd.DataFrame({
    'Actual': y_test_data.values.flatten(),  # 真实标签
    'Predicted_Prob': y_prob  # 预测的正类概率
})

# 保存为 CSV 文件
res_path = r"E:\liuzhou_breastcancer\test_result"
result_df.to_csv( res_path + r'\in_sub_0827.csv', index=False)
print("预测概率和实际标签已保存至 'in_sub_0427.csv'")
# Out:
# 测试集一共有214行特征数据，13列不同特征
# 在测试集上的准确率：0.7149532710280374
#
# 分类报告：
#               precision    recall  f1-score   support
#
#            0       0.49      0.30      0.37        60
#            1       0.76      0.88      0.82       154
#
#     accuracy                           0.71       214
#    macro avg       0.62      0.59      0.59       214
# weighted avg       0.69      0.71      0.69       214
#
#
# 整体结果:
# Sensitivity (召回率): 0.8766
# Specificity (特异性): 0.3000
# Precision (精确率): 0.7627
# F1-score: 0.8157
# AUC: 0.6823
# 预测概率和实际标签已保存至 'in_sub_0427.csv'

# %%
#绘制混淆矩阵
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import seaborn as sns
from sklearn.metrics import confusion_matrix

predict_label = model_forest.predict(x_test_data) # 预测的标签
label = y_test_data.values.tolist()  # 真实标签
confusion = confusion_matrix(label, predict_label) # 计算混淆矩阵

plt.figure(figsize=(6, 5))
sns.heatmap(confusion, cmap='Blues_r', annot=True, annot_kws={'size': 45, 'weight': 'bold'}) # 绘制混淆矩阵
plt.xlabel('Predict')
plt.ylabel('True')
plt.show()

print("混淆矩阵为：\n{}".format(confusion))
print("\n计算各项指标：")
print(classification_report(label, predict_label))
# Out:
# 混淆矩阵为：
# [[ 18  42]
#  [ 19 135]]
#
# 计算各项指标：
#               precision    recall  f1-score   support
#
#            0       0.49      0.30      0.37        60
#            1       0.76      0.88      0.82       154
#
#     accuracy                           0.71       214
#    macro avg       0.62      0.59      0.59       214
# weighted avg       0.69      0.71      0.69       214

# %%
#绘制ROC曲线,方法1
from sklearn.metrics import roc_curve, roc_auc_score,auc
kind = {'HGG':1,"LGG":0}
model_forest = joblib.load(model_path+'/'+model_name)#这是自己训练模型，记得替换自己的
label = y_test_data.values.tolist()  #真实标签
y_predict = model_forest.predict_proba(x_test_data)#得到标签0和1对应的概率h
fpr , tpr ,threshold = roc_curve(label, y_predict[:,kind['LGG']], pos_label=kind['LGG'])
roc_auc = auc(fpr,tpr) #计算auc的
fpr1 , tpr1 ,threshold = roc_curve(label, y_predict[:,kind['HGG']], pos_label=kind['HGG'])
roc_auc1 = auc(fpr1,tpr1) #计算auc的
plt.plot(fpr, tpr,marker='o', markersize=5,label='LGG')
plt.plot(fpr1, tpr1,marker='*', markersize=5,label='HGG')
plt.title("LGG AUC:{:.4f}, HGG AUC:{:.4f}".format(roc_auc,roc_auc1))
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc=4)
plt.show()

# %%
in_datapath = r"E:\breastcancer_new\radiology\in_habitat_test.csv"
val_data=pd.read_csv(in_datapath)

val_data.head()

filter_df = pd.read_csv(r'E:\breastcancer_new\datas_clear_pro.csv')  # 包含 patient_name, label_name, grade

# print(in_sub_data[['patient_name', 'label_name', 'grade']].isin(filter_df[['patient_name', 'label_name', 'grade']]))


for df in [val_data, filter_df]:
    df['patient_name'] = df['patient_name'].astype(str)
    df['label_name'] = df['label_name'].astype(str)
    df['grade'] = df['grade'].astype(int)


def filter_df_by_conditions(df, filter_df):
    # 合并方式：inner join（多列匹配）
    merged = df.merge(filter_df, on=['patient_name', 'grade'], how='inner')
    return merged
val_data = filter_df_by_conditions(val_data, filter_df)

print("过滤条件数：", len(filter_df))
print("筛选结果行数（in_data）：", len(val_data))

val_data.head()
# Out:
# 过滤条件数： 211
# 筛选结果行数（in_data）： 211
#    Unnamed: 0  grade patient_name         label_name_x  \
# 0           0      0    P00000963  P00000963seg.nii.gz
# 1           1      0    P00010632  P00010632seg.nii.gz
# 2           2      0    P00021942  P00021942seg.nii.gz
# 3           3      0    P00027530  P00027530seg.nii.gz
# 4           4      0    P00043786  P00043786seg.nii.gz
#
#       H1_diagnostics_Configuration_EnabledImageTypes  \
# 0  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 1  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 2  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 3  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 4  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
#
#                H1_diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#    H1_diagnostics_Image-interpolated_Maximum  \
# 0                                   1.712412
# 1                                   2.516320
# 2                                   2.710529
# 3                                   2.096886
# 4                                   1.238830
#
#    H1_diagnostics_Image-interpolated_Mean  \
# 0                                0.087423
# 1                                0.385675
# 2                                0.245137
# 3                                0.244310
# 4                                0.101199
#
#    H1_diagnostics_Image-interpolated_Minimum  \
# 0                                  -0.319708
# 1                                  -0.345447
# 2                                  -0.359440
# 3                                  -0.390107
# 4                                  -0.127425
#
#   H1_diagnostics_Image-interpolated_Size  ... H3_wavelet-LLL_ngtdm_Busyness  \
# 0                           (20, 23, 18)  ...                      1.242067
# 1                           (21, 22, 19)  ...                      0.563711
# 2                           (31, 30, 30)  ...                      0.783807
# 3                           (49, 46, 45)  ...                     24.510409
# 4                           (26, 23, 22)  ...                      2.412869
#
#   H3_wavelet-LLL_ngtdm_Coarseness H3_wavelet-LLL_ngtdm_Complexity  \
# 0                        0.078094                        2.398341
# 1                        0.036800                       17.226719
# 2                        0.014304                      114.381109
# 3                        0.000986                       11.691676
# 4                        0.024329                        5.006917
#
#    H3_wavelet-LLL_ngtdm_Contrast  H3_wavelet-LLL_ngtdm_Strength  index  \
# 0                       0.029781                       0.395728      0
# 1                       0.037159                       0.924275      1
# 2                       0.042926                       2.208655      2
# 3                       0.012029                       0.025254      3
# 4                       0.014103                       0.430682      5
#
#           label_name_y                                  nii_data  \
# 0  P00000963seg.nii.gz  E:\breastcancer_new\Benign_nii\P00000963
# 1  P00010632seg.nii.gz  E:\breastcancer_new\Benign_nii\P00010632
# 2  P00021942seg.nii.gz  E:\breastcancer_new\Benign_nii\P00021942
# 3  P00027530seg.nii.gz  E:\breastcancer_new\Benign_nii\P00027530
# 4  P00043786seg.nii.gz  E:\breastcancer_new\Benign_nii\P00043786
#
#                       dcm_data                                 label_path
# 0  E:\gz_data\Benign\P00000963  E:\gz_data\Benign_ROI\P00000963seg.nii.gz
# 1  E:\gz_data\Benign\P00010632  E:\gz_data\Benign_ROI\P00010632seg.nii.gz
# 2  E:\gz_data\Benign\P00021942  E:\gz_data\Benign_ROI\P00021942seg.nii.gz
# 3  E:\gz_data\Benign\P00027530  E:\gz_data\Benign_ROI\P00027530seg.nii.gz
# 4  E:\gz_data\Benign\P00043786  E:\gz_data\Benign_ROI\P00043786seg.nii.gz
#
# [5 rows x 3513 columns]

# %%
columns_index = pd_weight.index
x_val_data = val_data[columns_index]
y_val_data = val_data['grade']

print(x_val_data)
print(y_val_data)
# Out:
#      H2_log-sigma-1-0-mm-3D_glszm_LowGrayLevelZoneEmphasis  \
# 0                                             0.550000
# 1                                             0.718750
# 2                                             0.475926
# 3                                             0.352969
# 4                                             0.750000
# ..                                                 ...
# 206                                           0.222801
# 207                                           0.085114
# 208                                           0.189270
# 209                                           0.340710
# 210                                           0.359649
#
#      H1_log-sigma-1-0-mm-3D_glcm_Imc1  \
# 0                           -0.095641
# 1                           -0.125639
# 2                           -0.105048
# 3                           -0.131240
# 4                           -0.130233
# ..                                ...
# 206                         -0.168082
# 207                         -0.223269
# 208                         -0.166143
# 209                         -0.204930
# 210                         -0.197873
#
#      H1_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis  \
# 0                                             0.201041
# 1                                             0.112548
# 2                                             0.054869
# 3                                             0.060133
# 4                                             0.195221
# ..                                                 ...
# 206                                           0.032741
# 207                                           0.011173
# 208                                           0.050606
# 209                                           0.101604
# 210                                           0.040605
#
#      H2_log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized  \
# 0                                             1.000000
# 1                                             0.239669
# 2                                             0.500000
# 3                                             0.137778
# 4                                             0.312500
# ..                                                 ...
# 206                                           0.250000
# 207                                           0.226122
# 208                                           0.093750
# 209                                           0.167969
# 210                                           0.333333
#
#      H1_original_glszm_LowGrayLevelZoneEmphasis  \
# 0                                      0.625000
# 1                                      0.604167
# 2                                      0.467342
# 3                                      0.211821
# 4                                      0.863426
# ..                                          ...
# 206                                    0.140546
# 207                                    0.064373
# 208                                    0.595273
# 209                                    0.253510
# 210                                    0.216394
#
#      H1_wavelet-HLH_glcm_InverseVariance  H1_wavelet-LLL_ngtdm_Strength  \
# 0                               0.435752                       0.931345
# 1                               0.431587                       0.405457
# 2                               0.449607                       0.255022
# 3                               0.446637                       0.111161
# 4                               0.454852                       0.450892
# ..                                   ...                            ...
# 206                             0.426522                       0.163893
# 207                             0.422858                       0.144723
# 208                             0.448561                       0.081489
# 209                             0.429211                       0.022340
# 210                             0.439245                       0.137340
#
#      H1_wavelet-LLL_glrlm_RunVariance  \
# 0                            0.427253
# 1                            0.485152
# 2                            0.308451
# 3                            0.191274
# 4                            1.638958
# ..                                ...
# 206                          0.273812
# 207                          0.219517
# 208                          0.892782
# 209                          0.441114
# 210                          0.449200
#
#      H2_wavelet-HLH_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                             0.006915
# 1                                             0.206211
# 2                                             0.125001
# 3                                             0.381875
# 4                                             0.150821
# ..                                                 ...
# 206                                           0.077982
# 207                                           0.066986
# 208                                           0.241261
# 209                                           0.101517
# 210                                           0.198206
#
#      H2_wavelet-HHH_glszm_ZoneEntropy  H1_original_glszm_ZoneEntropy  \
# 0                            1.584963                       1.000000
# 1                            3.106048                       3.277613
# 2                            2.321928                       4.067165
# 3                            2.845144                       4.230135
# 4                            2.807355                       2.284159
# ..                                ...                            ...
# 206                          3.121928                       5.083442
# 207                          3.706191                       5.301869
# 208                          3.896665                       3.883427
# 209                          3.160446                       5.230251
# 210                          2.251629                       5.078807
#
#      H3_log-sigma-1-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis  \
# 0                                            16.003084
# 1                                             6.159707
# 2                                            42.238895
# 3                                            75.245895
# 4                                            18.081134
# ..                                                 ...
# 206                                          25.430233
# 207                                         343.549460
# 208                                          11.377394
# 209                                         165.606823
# 210                                          27.263808
#
#      H2_wavelet-HLL_glcm_Correlation
# 0                           0.173412
# 1                           0.347628
# 2                           0.251099
# 3                           0.287059
# 4                           0.253921
# ..                               ...
# 206                         0.254384
# 207                         0.354428
# 208                         0.272279
# 209                         0.322504
# 210                         0.193635
#
# [211 rows x 13 columns]
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 206    1
# 207    1
# 208    1
# 209    1
# 210    1
# Name: grade, Length: 211, dtype: int64

# %%
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from tabpfn import TabPFNClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline  # 必须使用imblearn的Pipeline
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, cross_validate

# N_SEEDS   = 1000               # 需要的随机种子数量
TEST_SIZE = 0.3                  # train/test 划分比例
CV_FOLDS  = 5                   # 10‑fold CV
RANDOM_BASE = 114514              # 生成种子列表的基准种子
RESULT_DIR = r"E:\liuzhou_breastcancer\eval_results-2"
MODEL_DIR  = r"E:\liuzhou_breastcancer\model-2"
CSV_NAME   = "in_habitat_top100_seeds.csv"
TEST_CSV   = "in_habitat_top100_seeds_test.csv"
EXT_CSV    = "in_habitat_top100_seeds_external.csv"
FINAL_MODEL_NAME = "in_habitat_top100.model"

scoring = {
    "accuracy": "accuracy",
    "sensitivity": make_scorer(recall_score, pos_label=1),
    "specificity": make_scorer(recall_score, pos_label=0),
    "precision": "precision",
    "f1": "f1",
    "auc": "roc_auc",
}

def compute_metrics(y_true, y_pred, y_proba):
    """返回六个指标的 dict"""
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "sensitivity": recall_score(y_true, y_pred, pos_label=1, zero_division=0),
        "specificity": recall_score(y_true, y_pred, pos_label=0, zero_division=0),
        "precision": precision_score(y_true, y_pred, zero_division=0),
        "f1": f1_score(y_true, y_pred, zero_division=0),
        "auc": roc_auc_score(y_true, y_proba),
    }

def build_pipeline(seed):
    """构建包含 StandardScaler、SMOTE、TabPFN 的 Pipeline"""
    return Pipeline([
        ("scaler", StandardScaler()),
        ("sampler", SMOTE(sampling_strategy=0.9, random_state=seed)),
        ("classifier", TabPFNClassifier(
            random_state=seed,
            softmax_temperature=0.8,
            balance_probabilities=True,
            memory_saving_mode=True,
            device='cuda'   # 若无 GPU 改为 'cpu'
        )),
    ])

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_all = x
X_all = X_all[pd_weight.index]
y_all = y

print(X_all.shape)

def evaluate_one_seed(seed, x_val_data, y_val_data):
    """对单个随机种子完成划分、CV、Test、External 并返回结果列表"""
    # ① 训练/测试划分
    X_train, X_test, y_train, y_test = train_test_split(
        X_all, y_all,
        test_size=TEST_SIZE,
        stratify=y_all,
        random_state=seed,
    )
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # ② 10‑fold CV（仅在训练集内部）
    cv = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=seed)
    pipeline = build_pipeline(seed)
    cv_scores = cross_validate(
        pipeline, X_train, y_train,
        cv=cv,
        scoring=scoring,
        n_jobs=1,               # 防止内部并行与外部并行冲突
        return_estimator=False,
    )

    # ③ 在完整训练集上再次 fit（用于后面的 Test / External 评估）
    pipeline.fit(X_train, y_train)

    # ④ Test 集评估
    y_test_pred = pipeline.predict(X_test)
    y_test_proba = pipeline.predict_proba(X_test)[:, 1]
    test_metrics = compute_metrics(y_test, y_test_pred, y_test_proba)

    # ⑤ External 验证（若提供）
    external_metrics = None
    if x_val_data is not None and y_val_data is not None:
        x_val_scaled = scaler.transform(x_val_data)
        y_ext_pred = pipeline.predict(x_val_scaled)
        y_ext_proba = pipeline.predict_proba(x_val_scaled)[:, 1]
        
        external_metrics = compute_metrics(y_val_data, y_ext_pred, y_ext_proba)

    # ⑥ 整理所有行
    rows = []

    # CV 每折一行
    for fold_id in range(CV_FOLDS):
        rows.append({
            "seed": seed,
            "split_type": "CV",
            "repeat_id": 0,               # 本例中没有 repeat，仅占位
            "fold_id": fold_id,
            "accuracy": cv_scores["test_accuracy"][fold_id],
            "sensitivity": cv_scores["test_sensitivity"][fold_id],
            "specificity": cv_scores["test_specificity"][fold_id],
            "precision": cv_scores["test_precision"][fold_id],
            "f1": cv_scores["test_f1"][fold_id],
            "auc": cv_scores["test_auc"][fold_id],
        })

    # Test 一行
    rows.append({
        "seed": seed,
        "split_type": "TEST",
        "repeat_id": np.nan,
        "fold_id": np.nan,
        **test_metrics,
    })

    # External 一行（若有）
    if external_metrics is not None:
        rows.append({
            "seed": seed,
            "split_type": "EXTERNAL",
            "repeat_id": np.nan,
            "fold_id": np.nan,
            **external_metrics,
        })

    return rows
# Out:
# (712, 13)

# %%
# 使用100个可复现的随机种子
from tqdm.notebook import tqdm
from joblib import Parallel, delayed, dump
import joblib
# rng = np.random.RandomState(RANDOM_BASE)
# seed_list = rng.randint(300001, 400000, size=N_SEEDS)
seed_list = [2537, 10880, 132453, 42539, 149191, 21903, 38176, 148376, 109335, 21932,
    85431, 172241, 102225, 297262, 266651, 48322, 41855, 20322, 165600, 22096,
    238541, 160128, 8170, 10876, 176597, 60977, 272441, 19873, 24623, 273843,
    284060, 41744, 158808, 49641, 234691, 11975, 126250, 129794, 79842, 168393,
    7094, 232214, 137044, 19597, 266215, 108991, 53031, 285336, 174992, 243942,
    140470, 57264, 1746, 23071, 192121, 191306, 287145, 101180, 52765, 180735,
    112074, 40083, 197733, 93286, 204889, 226555, 57712, 140084, 71943, 185676,
    279288, 190760, 45149, 73280, 259534, 87578, 42474, 60495, 108145, 20879,
    59695, 290404, 8987, 76984, 98109, 19759, 89914, 104079, 202196, 70586,
    25537, 240437, 59147, 75810, 129464, 143460, 293508, 30130, 158100, 125463]

# 使用 joblib 并行执行；n_jobs=-1 使用全部 CPU 核心
all_rows = Parallel(n_jobs=-1, backend="loky", verbose=5)(
    delayed(evaluate_one_seed)(seed, x_val_data, y_val_data) for seed in tqdm(seed_list, desc="Seeds")
)

    # flatten
flat_rows = [row for sublist in all_rows for row in sublist]
df = pd.DataFrame(flat_rows)

# ------------------- 6. 保存 CSV -------------------
os.makedirs(RESULT_DIR, exist_ok=True)

# 统一的完整 CSV（包含 CV、TEST、EXTERNAL）
combined_path = os.path.join(RESULT_DIR, CSV_NAME)
df.to_csv(combined_path, index=False, encoding="utf-8")
print(f"✅ 完整结果已保存到 {combined_path}")

# 仅保留 TEST 行的 CSV
test_df = df.query("split_type == 'TEST'").drop(columns=["split_type"])
test_path = os.path.join(RESULT_DIR, TEST_CSV)
test_df.to_csv(test_path, index=False, encoding="utf-8")
print(f"✅ 测试集结果已保存到 {test_path}")

    # 仅保留 EXTERNAL 行的 CSV（若有外部验证集）
if x_val_data is not None:
    ext_df = df.query("split_type == 'EXTERNAL'").drop(columns=["split_type"])
    ext_path = os.path.join(RESULT_DIR, EXT_CSV)
    ext_df.to_csv(ext_path, index=False, encoding="utf-8")
    print(f"✅ 外部验证集结果已保存到 {ext_path}")
else:
    print("⚠️ 未提供外部验证集，跳过外部 CSV 的生成。")

    # ------------------- 7. 训练全量模型并保存 -------------------
final_pipe = build_pipeline(seed=RANDOM_BASE)
final_pipe.fit(X_all, y_all)

os.makedirs(MODEL_DIR, exist_ok=True)
model_path = os.path.join(MODEL_DIR, FINAL_MODEL_NAME)
joblib.dump(final_pipe, model_path)
print(f"🗂️ 全量模型已保存到 {model_path}")
# Out:
# Seeds:   0%|          | 0/100 [00:00<?, ?it/s]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  58 out of 100 | elapsed:  3.8min remaining:  2.7min
# [Parallel(n_jobs=-1)]: Done  79 out of 100 | elapsed:  5.4min remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  5.6min finished
# ✅ 完整结果已保存到 E:\liuzhou_breastcancer\eval_results-2\in_habitat_top100_seeds.csv
# ✅ 测试集结果已保存到 E:\liuzhou_breastcancer\eval_results-2\in_habitat_top100_seeds_test.csv
# ✅ 外部验证集结果已保存到 E:\liuzhou_breastcancer\eval_results-2\in_habitat_top100_seeds_external.csv
# 🗂️ 全量模型已保存到 E:\liuzhou_breastcancer\model-2\in_habitat_top100.model

# %%
# -------------------------------------------------
# ① 依据 split_type == "CV" 取出所有 CV 折的记录
cv_df = df[df["split_type"] == "CV"].copy()

# 需要统计的指标（与后面 compute_metrics 中保持一致）
metrics = ["accuracy", "sensitivity", "specificity", "precision", "f1", "auc"]

# ② 按 seed 分组，求 mean 与 std
cv_summary = (
    cv_df.groupby("seed")[metrics]
    .agg(["mean", "std"])                     # 生成 MultiIndex 列
    .reset_index()
)

# ③ 把 MultiIndex 的列名展平成 “metric_mean / metric_std”
cv_summary.columns = [
    f"{metric}_{stat}" if stat else metric
    for metric, stat in cv_summary.columns
]

# ④ 保存到 CSV（文件名自行修改）
cv_summary_path = os.path.join(RESULT_DIR, "in_habitat_top100_seeds_cv_summary.csv")
cv_summary.to_csv(cv_summary_path, index=False, encoding="utf-8")
print(f"✅ 10‑折 CV 均值/标准差已保存到 {cv_summary_path}")
# Out:
# ✅ 10‑折 CV 均值/标准差已保存到 E:\liuzhou_breastcancer\eval_results-2\in_habitat_top100_seeds_cv_summary.csv

# %%
# -------------------------------------------------
# 为了拼接，先把 test / external 的列名加上后缀，防止冲突
# ① Test
test_df_clean = (
    test_df.drop(columns=["repeat_id", "fold_id"])
    .rename(columns=lambda c: f"{c}_test" if c not in ["seed"] else c)
)

# ② External（若提供）
if x_val_data is not None:
    ext_df_clean = (
        ext_df.drop(columns=["repeat_id", "fold_id"])
        .rename(columns=lambda c: f"{c}_external" if c not in ["seed"] else c)
    )
else:
    ext_df_clean = None

# -------------------------------------------------
# ③ 合并：先左连接 CV summary → Test → External
combined_df = cv_summary.merge(test_df_clean, on="seed", how="left")

if ext_df_clean is not None:
    combined_df = combined_df.merge(ext_df_clean, on="seed", how="left")

# -------------------------------------------------
# ④ 保存最终的拼接文件
combined_path = os.path.join(RESULT_DIR, "in_habitat_top100_seeds_all_combined.csv")
combined_df.to_csv(combined_path, index=False, encoding="utf-8")
print(f"✅ 所有信息已按列拼接并保存到 {combined_path}")
# Out:
# ✅ 所有信息已按列拼接并保存到 E:\liuzhou_breastcancer\eval_results-2\in_habitat_top100_seeds_all_combined.csv

# %%
# Code source: Gaël Varoquaux
#              Andreas Müller
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.inspection import DecisionBoundaryDisplay
import warnings


names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]
seed=42
classifiers = [
    KNeighborsClassifier(2),
    SVC(kernel="linear", C=0.025,probability=True,random_state=seed),
    SVC(gamma=2, C=1,probability=True,random_state=seed),
    GaussianProcessClassifier(1.0 * RBF(1.0),random_state=seed),
    DecisionTreeClassifier(max_depth=5,random_state=seed),
    RandomForestClassifier(max_depth=5, n_estimators=100, max_features=10,random_state=seed),
    MLPClassifier(alpha=1, max_iter=1000,random_state=seed),
    AdaBoostClassifier(random_state=seed),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
]

for name, clf in zip(names, classifiers):
    clf = make_pipeline(StandardScaler(), clf)
    clf.fit(rforest_x, rforest_y)
    pred_y= clf.predict(x_test_data)
    pred_y_proba = clf.predict_proba(x_test_data)
    accuracy=metrics.accuracy_score(y_test_data,pred_y)
    balanced_accuracy=metrics.balanced_accuracy_score(y_test_data,pred_y)
    f1_weighted=metrics.f1_score(y_test_data,pred_y)
    precision=metrics.precision_score(y_test_data,pred_y)
    sensitivity=metrics.precision_score(y_test_data,pred_y)
    tn,fp,fn,tp=confusion_matrix(y_test_data,pred_y).ravel()
    specificity=tn/(tn+fp)
    AUC=metrics.roc_auc_score(y_test_data,pred_y_proba[:,-1])
    print(name+'\n'+'accuracy: '+str(accuracy)[:6]
          +', sensitivity: '+str(sensitivity)[:6]
          +', specificity: '+str(specificity)[:6]
          +', precision: '+str(precision)[:6]
          +', f1_weighted: '+str(f1_weighted)[:6]
          +', AUC: '+str(AUC)[:6])
    # print(pred_y)
    # break
    # print(name+' '+str(score))
# Out:
# Nearest Neighbors
# accuracy: 0.7024, sensitivity: 0.8695, specificity: 0.7419, precision: 0.8695, f1_weighted: 0.7673, AUC: 0.7312
# Linear SVM
# accuracy: 0.7423, sensitivity: 0.7595, specificity: 0.2580, precision: 0.7595, f1_weighted: 0.8384, AUC: 0.7536
# RBF SVM
# accuracy: 0.8006, sensitivity: 0.7818, specificity: 0.3010, precision: 0.7818, f1_weighted: 0.8775, AUC: 0.8075
# Gaussian Process
# accuracy: 0.7300, sensitivity: 0.7799, specificity: 0.3870, precision: 0.7799, f1_weighted: 0.8211, AUC: 0.7769
# Decision Tree
# accuracy: 0.7361, sensitivity: 0.7732, specificity: 0.3440, precision: 0.7732, f1_weighted: 0.8286, AUC: 0.7446
# Random Forest
# accuracy: 0.7730, sensitivity: 0.7955, specificity: 0.4086, precision: 0.7955, f1_weighted: 0.8525, AUC: 0.8193
# Neural Net
# accuracy: 0.7576, sensitivity: 0.8104, specificity: 0.4946, precision: 0.8104, f1_weighted: 0.8357, AUC: 0.8055
# AdaBoost
# accuracy: 0.7423, sensitivity: 0.8065, specificity: 0.4946, precision: 0.8065, f1_weighted: 0.8235, AUC: 0.7542
# Naive Bayes
# accuracy: 0.7024, sensitivity: 0.7764, specificity: 0.4086, precision: 0.7764, f1_weighted: 0.7974, AUC: 0.7458
# QDA
# accuracy: 0.7331, sensitivity: 0.7786, specificity: 0.3763, precision: 0.7786, f1_weighted: 0.8242, AUC: 0.7669

# %%
index = pd_weight.index
rforest_x = X_train.loc[:,index]
rforest_x['label']=y_train
rforest_x.to_csv('model_data/train.csv')
x_test_data = X_test.loc[:,index]
x_test_data['label']=y_test_data
x_test_data.to_csv('model_data/test.csv')
